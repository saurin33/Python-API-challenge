# %%
pip install citipy
# Out:
# Collecting citipy
#   Downloading https://files.pythonhosted.org/packages/3b/d0/59721d0f3954781488aac17ee4a40412d0a3547e98bb16377a09c39a2807/citipy-0.0.5.tar.gz (557kB)
#      |████████████████████████████████| 563kB 1.2MB/s eta 0:00:01
# Collecting kdtree>=0.12 (from citipy)
#   Downloading https://files.pythonhosted.org/packages/00/3d/bd727d025b1706798aae14da3f69fc7d5a8639dc9e0eba37c7dcd43eb03e/kdtree-0.16-py2.py3-none-any.whl
# Building wheels for collected packages: citipy
#   Building wheel for citipy (setup.py) ... done
#   Created wheel for citipy: filename=citipy-0.0.5-cp37-none-any.whl size=559703 sha256=3836d786320430a077d9ae1ad77915c6dcae339cac45dbdda7364bef439a7b4b
#   Stored in directory: /Users/saurin/Library/Caches/pip/wheels/6f/07/0d/0392639cf1c10376f59decd06775c0e085ca2458c6036c1028
# Successfully built citipy
# Installing collected packages: kdtree, citipy
# Successfully installed citipy-0.0.5 kdtree-0.16
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
from api_keys import weather_api_key
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import time
from scipy.stats import stats

# %%
output_data_file = "output_data/cities.csv"
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# print(cities)
# Out:
# 618

# %%
new_cities = []
cloudiness = []
country = []
date = []
humidity = []
temp = []
lat = []
lng = []
wind = []

# %%
record_count = 0
set_count = 0
# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key 
print('------------------------')
print('Beginning Data Retrieval')
print('------------------------')

for city in cities:
    query_url = url + "&q=" + city
    # Get weather data
    response = requests.get(query_url).json()
    if record_count < 50:
        record_count += 1
    else:
        set_count += 1
        record_count = 0

    print('Processing record {} of set {} | {}'.format(record_count, set_count, city))
    print(query_url)
    try:
        cloudiness.append(response['clouds']['all'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        humidity.append(response['main']['humidity'])
        temp.append(response['main']['temp_max'])
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        wind.append(response['wind']['speed'])
        new_cities.append(city)
    except:
        print("City not found!")
        pass

print('-------------------------')
print('Data Retrieval Complete')
print('-------------------------')
# Out:
# ------------------------
# Beginning Data Retrieval
# ------------------------
# Processing record 1 of set 0 | jamestown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=jamestown
# Processing record 2 of set 0 | marzuq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=marzuq
# Processing record 3 of set 0 | yishui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=yishui
# Processing record 4 of set 0 | hobart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=hobart
# Processing record 5 of set 0 | namibe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=namibe
# Processing record 6 of set 0 | saleaula
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=saleaula
# City not found!
# Processing record 7 of set 0 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=punta arenas
# Processing record 8 of set 0 | kuching
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=kuching
# Processing record 9 of set 0 | hilo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=hilo
# Processing record 10 of set 0 | rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=rikitea
# Processing record 11 of set 0 | pevek
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=pevek
# Processing record 12 of set 0 | nyurba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=nyurba
# Processing record 13 of set 0 | asopos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=asopos
# Processing record 14 of set 0 | taolanaro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=taolanaro
# City not found!
# Processing record 15 of set 0 | jiddah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=jiddah
# City not found!
# Processing record 16 of set 0 | meulaboh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=meulaboh
# Processing record 17 of set 0 | eufaula
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=eufaula
# Processing record 18 of set 0 | avarua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=avarua
# Processing record 19 of set 0 | puerto ayora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=puerto ayora
# Processing record 20 of set 0 | georgetown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=georgetown
# Processing record 21 of set 0 | sembakung
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=sembakung
# Processing record 22 of set 0 | castro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=castro
# Processing record 23 of set 0 | busselton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=busselton
# Processing record 24 of set 0 | nanchang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=nanchang
# Processing record 25 of set 0 | brae
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=brae
# Processing record 26 of set 0 | bethel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=bethel
# Processing record 27 of set 0 | carnarvon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=carnarvon
# Processing record 28 of set 0 | kapaa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=kapaa
# Processing record 29 of set 0 | hofn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=hofn
# Processing record 30 of set 0 | kudahuvadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=kudahuvadhoo
# Processing record 31 of set 0 | port alfred
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=port alfred
# Processing record 32 of set 0 | kodiak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=kodiak
# Processing record 33 of set 0 | norman wells
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=norman wells
# Processing record 34 of set 0 | korem
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=korem
# Processing record 35 of set 0 | hermanus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=hermanus
# Processing record 36 of set 0 | safford
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=safford
# Processing record 37 of set 0 | upernavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=upernavik
# Processing record 38 of set 0 | cherskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=cherskiy
# Processing record 39 of set 0 | warrington
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=warrington
# Processing record 40 of set 0 | chokurdakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=chokurdakh
# Processing record 41 of set 0 | dikson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=dikson
# Processing record 42 of set 0 | warmbad
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=warmbad
# Processing record 43 of set 0 | barawe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=barawe
# City not found!
# Processing record 44 of set 0 | kaitangata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=kaitangata
# Processing record 45 of set 0 | ribeira grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=ribeira grande
# Processing record 46 of set 0 | carnduff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=carnduff
# Processing record 47 of set 0 | tessalit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=tessalit
# Processing record 48 of set 0 | nuevo progreso
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=nuevo progreso
# Processing record 49 of set 0 | albany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=albany
# Processing record 50 of set 0 | ichhawar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=ichhawar
# Processing record 0 of set 1 | ponta do sol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=ponta do sol
# Processing record 1 of set 1 | tasiilaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=tasiilaq
# Processing record 2 of set 1 | manado
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=manado
# Processing record 3 of set 1 | victoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=victoria
# Processing record 4 of set 1 | mar del plata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=mar del plata
# Processing record 5 of set 1 | saldanha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=saldanha
# Processing record 6 of set 1 | pozo colorado
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=pozo colorado
# Processing record 7 of set 1 | ust-nera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=ust-nera
# Processing record 8 of set 1 | abu samrah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=abu samrah
# Processing record 9 of set 1 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=bredasdorp
# Processing record 10 of set 1 | vaini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=vaini
# Processing record 11 of set 1 | tuy hoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=tuy hoa
# Processing record 12 of set 1 | pacific grove
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=pacific grove
# Processing record 13 of set 1 | henties bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=henties bay
# Processing record 14 of set 1 | barrow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=barrow
# Processing record 15 of set 1 | laguna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=laguna
# Processing record 16 of set 1 | petukhovo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=petukhovo
# Processing record 17 of set 1 | manta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=manta
# Processing record 18 of set 1 | saskylakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=saskylakh
# Processing record 19 of set 1 | sao filipe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=sao filipe
# Processing record 20 of set 1 | solnechnyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=solnechnyy
# Processing record 21 of set 1 | mortka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=mortka
# Processing record 22 of set 1 | atuona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=atuona
# Processing record 23 of set 1 | mataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=mataura
# Processing record 24 of set 1 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=ushuaia
# Processing record 25 of set 1 | tiksi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=tiksi
# Processing record 26 of set 1 | alofi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=alofi
# Processing record 27 of set 1 | warqla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=warqla
# City not found!
# Processing record 28 of set 1 | tacuarembo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=tacuarembo
# Processing record 29 of set 1 | cape town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=cape town
# Processing record 30 of set 1 | clyde river
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=clyde river
# Processing record 31 of set 1 | caravelas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=caravelas
# Processing record 32 of set 1 | aklavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=aklavik
# Processing record 33 of set 1 | butaritari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=butaritari
# Processing record 34 of set 1 | chenzhou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=chenzhou
# Processing record 35 of set 1 | thompson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=thompson
# Processing record 36 of set 1 | aksarka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=aksarka
# Processing record 37 of set 1 | novopokrovka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=novopokrovka
# Processing record 38 of set 1 | acari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=acari
# Processing record 39 of set 1 | ascoli piceno
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=ascoli piceno
# Processing record 40 of set 1 | attawapiskat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=attawapiskat
# City not found!
# Processing record 41 of set 1 | calatayud
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=calatayud
# Processing record 42 of set 1 | belushya guba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=belushya guba
# City not found!
# Processing record 43 of set 1 | torbay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=torbay
# Processing record 44 of set 1 | qazanbulaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=qazanbulaq
# Processing record 45 of set 1 | iqaluit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=iqaluit
# Processing record 46 of set 1 | esperance
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=esperance
# Processing record 47 of set 1 | east london
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=east london
# Processing record 48 of set 1 | imeni poliny osipenko
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=imeni poliny osipenko
# Processing record 49 of set 1 | ketchikan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=ketchikan
# Processing record 50 of set 1 | tadine
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=tadine
# Processing record 0 of set 2 | illoqqortoormiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=illoqqortoormiut
# City not found!
# Processing record 1 of set 2 | takoradi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=takoradi
# Processing record 2 of set 2 | kisangani
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=kisangani
# Processing record 3 of set 2 | dudinka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=dudinka
# Processing record 4 of set 2 | mount pleasant
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=mount pleasant
# Processing record 5 of set 2 | sisimiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=sisimiut
# Processing record 6 of set 2 | bluff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=bluff
# Processing record 7 of set 2 | viedma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=viedma
# Processing record 8 of set 2 | tefe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=tefe
# Processing record 9 of set 2 | roebourne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=roebourne
# Processing record 10 of set 2 | marienburg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=marienburg
# Processing record 11 of set 2 | farafangana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=farafangana
# Processing record 12 of set 2 | severo-yeniseyskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=severo-yeniseyskiy
# Processing record 13 of set 2 | hithadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=hithadhoo
# Processing record 14 of set 2 | moree
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=moree
# Processing record 15 of set 2 | sioux lookout
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=sioux lookout
# Processing record 16 of set 2 | talnakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=talnakh
# Processing record 17 of set 2 | cabra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=cabra
# Processing record 18 of set 2 | hamilton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=hamilton
# Processing record 19 of set 2 | ruwi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=ruwi
# Processing record 20 of set 2 | gallup
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=gallup
# Processing record 21 of set 2 | sorvag
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=sorvag
# City not found!
# Processing record 22 of set 2 | palabuhanratu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=palabuhanratu
# City not found!
# Processing record 23 of set 2 | yellowknife
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=yellowknife
# Processing record 24 of set 2 | along
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=along
# Processing record 25 of set 2 | severo-kurilsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=severo-kurilsk
# Processing record 26 of set 2 | cairns
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=cairns
# Processing record 27 of set 2 | riyadh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=riyadh
# Processing record 28 of set 2 | barentsburg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=barentsburg
# City not found!
# Processing record 29 of set 2 | hualmay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=hualmay
# Processing record 30 of set 2 | vaitupu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=vaitupu
# City not found!
# Processing record 31 of set 2 | louisbourg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=louisbourg
# City not found!
# Processing record 32 of set 2 | rujiena
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=rujiena
# Processing record 33 of set 2 | new norfolk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=new norfolk
# Processing record 34 of set 2 | purranque
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=purranque
# Processing record 35 of set 2 | am timan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=am timan
# Processing record 36 of set 2 | taos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=taos
# Processing record 37 of set 2 | coihaique
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=coihaique
# Processing record 38 of set 2 | bajo baudo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=bajo baudo
# City not found!
# Processing record 39 of set 2 | luorong
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=luorong
# Processing record 40 of set 2 | beyla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=beyla
# Processing record 41 of set 2 | guerrero negro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=guerrero negro
# Processing record 42 of set 2 | santa cruz del norte
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=santa cruz del norte
# Processing record 43 of set 2 | gospic
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=gospic
# Processing record 44 of set 2 | lata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=lata
# Processing record 45 of set 2 | nikolskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=nikolskoye
# Processing record 46 of set 2 | provideniya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=provideniya
# Processing record 47 of set 2 | sedona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=sedona
# Processing record 48 of set 2 | luderitz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=luderitz
# Processing record 49 of set 2 | koungou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=koungou
# Processing record 50 of set 2 | khasan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=khasan
# Processing record 0 of set 3 | dengfeng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=dengfeng
# Processing record 1 of set 3 | jambi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=jambi
# Processing record 2 of set 3 | ambodifototra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=ambodifototra
# City not found!
# Processing record 3 of set 3 | kruisfontein
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=kruisfontein
# Processing record 4 of set 3 | tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=tuktoyaktuk
# Processing record 5 of set 3 | skjervoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=skjervoy
# Processing record 6 of set 3 | andenes
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=andenes
# Processing record 7 of set 3 | bengkulu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=bengkulu
# Processing record 8 of set 3 | sao joao da barra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=sao joao da barra
# Processing record 9 of set 3 | samarai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=samarai
# Processing record 10 of set 3 | grand river south east
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=grand river south east
# City not found!
# Processing record 11 of set 3 | malumfashi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=malumfashi
# Processing record 12 of set 3 | ahipara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=ahipara
# Processing record 13 of set 3 | vardo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=vardo
# Processing record 14 of set 3 | sergeyevka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=sergeyevka
# Processing record 15 of set 3 | mys shmidta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=mys shmidta
# City not found!
# Processing record 16 of set 3 | nouadhibou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=nouadhibou
# Processing record 17 of set 3 | puerto narino
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=puerto narino
# Processing record 18 of set 3 | tukrah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=tukrah
# Processing record 19 of set 3 | ambilobe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=ambilobe
# Processing record 20 of set 3 | victoria point
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=victoria point
# Processing record 21 of set 3 | dwarka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=dwarka
# Processing record 22 of set 3 | amuntai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=amuntai
# Processing record 23 of set 3 | skibbereen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=skibbereen
# Processing record 24 of set 3 | beni mazar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=beni mazar
# Processing record 25 of set 3 | port lincoln
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=port lincoln
# Processing record 26 of set 3 | sinnamary
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=sinnamary
# Processing record 27 of set 3 | lavrentiya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=lavrentiya
# Processing record 28 of set 3 | bonthe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=bonthe
# Processing record 29 of set 3 | qaanaaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=qaanaaq
# Processing record 30 of set 3 | luanda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=luanda
# Processing record 31 of set 3 | creel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=creel
# Processing record 32 of set 3 | vao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=vao
# Processing record 33 of set 3 | san patricio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=san patricio
# Processing record 34 of set 3 | berlevag
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=berlevag
# Processing record 35 of set 3 | grindavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=grindavik
# Processing record 36 of set 3 | sataua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=sataua
# City not found!
# Processing record 37 of set 3 | baglan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=baglan
# Processing record 38 of set 3 | mecca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=mecca
# Processing record 39 of set 3 | boditi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=boditi
# Processing record 40 of set 3 | codrington
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=codrington
# Processing record 41 of set 3 | ponta delgada
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=ponta delgada
# Processing record 42 of set 3 | san juan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=san juan
# Processing record 43 of set 3 | kununurra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=kununurra
# Processing record 44 of set 3 | lagoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=lagoa
# Processing record 45 of set 3 | laiyang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=laiyang
# Processing record 46 of set 3 | gijon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=gijon
# Processing record 47 of set 3 | leningradskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=leningradskiy
# Processing record 48 of set 3 | chuy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=chuy
# Processing record 49 of set 3 | tumannyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=tumannyy
# City not found!
# Processing record 50 of set 3 | ilhabela
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=ilhabela
# Processing record 0 of set 4 | agirish
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=agirish
# Processing record 1 of set 4 | ijaki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=ijaki
# City not found!
# Processing record 2 of set 4 | chapais
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=chapais
# Processing record 3 of set 4 | salinopolis
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=salinopolis
# Processing record 4 of set 4 | novoagansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=novoagansk
# Processing record 5 of set 4 | oga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=oga
# Processing record 6 of set 4 | kangaba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=kangaba
# Processing record 7 of set 4 | srednekolymsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=srednekolymsk
# Processing record 8 of set 4 | storslett
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=storslett
# Processing record 9 of set 4 | sentyabrskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=sentyabrskiy
# City not found!
# Processing record 10 of set 4 | talara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=talara
# Processing record 11 of set 4 | odweyne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=odweyne
# Processing record 12 of set 4 | souillac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=souillac
# Processing record 13 of set 4 | cidreira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=cidreira
# Processing record 14 of set 4 | thinadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=thinadhoo
# Processing record 15 of set 4 | lompoc
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=lompoc
# Processing record 16 of set 4 | xuanwu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=xuanwu
# Processing record 17 of set 4 | nishihara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=nishihara
# Processing record 18 of set 4 | marinskaya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=marinskaya
# City not found!
# Processing record 19 of set 4 | ruatoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=ruatoria
# City not found!
# Processing record 20 of set 4 | asau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=asau
# Processing record 21 of set 4 | prainha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=prainha
# Processing record 22 of set 4 | asha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=asha
# Processing record 23 of set 4 | tuatapere
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=tuatapere
# Processing record 24 of set 4 | vostok
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=vostok
# Processing record 25 of set 4 | saint-philippe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=saint-philippe
# Processing record 26 of set 4 | rindal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=rindal
# Processing record 27 of set 4 | saint-augustin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=saint-augustin
# Processing record 28 of set 4 | touros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=touros
# Processing record 29 of set 4 | port elizabeth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=port elizabeth
# Processing record 30 of set 4 | faanui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=faanui
# Processing record 31 of set 4 | constitucion
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=constitucion
# Processing record 32 of set 4 | balkanabat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=balkanabat
# Processing record 33 of set 4 | dunedin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=dunedin
# Processing record 34 of set 4 | kavieng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=kavieng
# Processing record 35 of set 4 | estevan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=estevan
# Processing record 36 of set 4 | tonj
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=tonj
# Processing record 37 of set 4 | warri
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=warri
# Processing record 38 of set 4 | anadyr
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=anadyr
# Processing record 39 of set 4 | ushtobe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=ushtobe
# Processing record 40 of set 4 | bouza
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=bouza
# Processing record 41 of set 4 | rungata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=rungata
# City not found!
# Processing record 42 of set 4 | umzimvubu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=umzimvubu
# City not found!
# Processing record 43 of set 4 | katsuura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=katsuura
# Processing record 44 of set 4 | tilichiki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=tilichiki
# Processing record 45 of set 4 | ahuimanu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=ahuimanu
# Processing record 46 of set 4 | kahului
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=kahului
# Processing record 47 of set 4 | vila
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=vila
# Processing record 48 of set 4 | longyearbyen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=longyearbyen
# Processing record 49 of set 4 | nusaybin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=nusaybin
# Processing record 50 of set 4 | ugoofaaru
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=ugoofaaru
# Processing record 0 of set 5 | mahmudabad
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=mahmudabad
# Processing record 1 of set 5 | te anau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=te anau
# Processing record 2 of set 5 | bairiki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=bairiki
# Processing record 3 of set 5 | auki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=auki
# Processing record 4 of set 5 | la rioja
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=la rioja
# Processing record 5 of set 5 | karibib
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=karibib
# Processing record 6 of set 5 | udhampur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=udhampur
# Processing record 7 of set 5 | husavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=husavik
# Processing record 8 of set 5 | diego de almagro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=diego de almagro
# Processing record 9 of set 5 | saint george
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=saint george
# Processing record 10 of set 5 | north myrtle beach
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=north myrtle beach
# Processing record 11 of set 5 | minab
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=minab
# Processing record 12 of set 5 | arlit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=arlit
# Processing record 13 of set 5 | itoman
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=itoman
# Processing record 14 of set 5 | khatanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=khatanga
# Processing record 15 of set 5 | launceston
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=launceston
# Processing record 16 of set 5 | zyryanka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=zyryanka
# Processing record 17 of set 5 | portland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=portland
# Processing record 18 of set 5 | khudumelapye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=khudumelapye
# Processing record 19 of set 5 | artyk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=artyk
# City not found!
# Processing record 20 of set 5 | yumen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=yumen
# Processing record 21 of set 5 | callaguip
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=callaguip
# Processing record 22 of set 5 | sembe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=sembe
# Processing record 23 of set 5 | athabasca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=athabasca
# Processing record 24 of set 5 | port hardy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=port hardy
# Processing record 25 of set 5 | kavaratti
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=kavaratti
# Processing record 26 of set 5 | port hueneme
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=port hueneme
# Processing record 27 of set 5 | nizhneyansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=nizhneyansk
# City not found!
# Processing record 28 of set 5 | centralia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=centralia
# Processing record 29 of set 5 | nisia floresta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=nisia floresta
# Processing record 30 of set 5 | aykhal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=aykhal
# Processing record 31 of set 5 | mayumba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=mayumba
# Processing record 32 of set 5 | geraldton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=geraldton
# Processing record 33 of set 5 | itarema
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=itarema
# Processing record 34 of set 5 | katangli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=katangli
# Processing record 35 of set 5 | kloulklubed
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=kloulklubed
# Processing record 36 of set 5 | healdsburg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=healdsburg
# Processing record 37 of set 5 | matai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=matai
# Processing record 38 of set 5 | bac lieu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=bac lieu
# Processing record 39 of set 5 | honningsvag
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=honningsvag
# Processing record 40 of set 5 | coquimbo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=coquimbo
# Processing record 41 of set 5 | magdagachi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=magdagachi
# Processing record 42 of set 5 | san cristobal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=san cristobal
# Processing record 43 of set 5 | upata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=upata
# Processing record 44 of set 5 | vila franca do campo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=vila franca do campo
# Processing record 45 of set 5 | hasaki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=hasaki
# Processing record 46 of set 5 | half moon bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=half moon bay
# Processing record 47 of set 5 | bose
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=bose
# Processing record 48 of set 5 | sabancuy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=sabancuy
# Processing record 49 of set 5 | arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=arraial do cabo
# Processing record 50 of set 5 | hami
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=hami
# Processing record 0 of set 6 | shurugwi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=shurugwi
# Processing record 1 of set 6 | laurel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=laurel
# Processing record 2 of set 6 | sandpoint
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=sandpoint
# Processing record 3 of set 6 | mombetsu
# ...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=jodhpur
# Processing record 7 of set 10 | ayan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=ayan
# Processing record 8 of set 10 | taoudenni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=taoudenni
# Processing record 9 of set 10 | dicabisagan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=dicabisagan
# Processing record 10 of set 10 | olgod
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=olgod
# Processing record 11 of set 10 | save
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=save
# Processing record 12 of set 10 | aktas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=aktas
# Processing record 13 of set 10 | samalaeulu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=samalaeulu
# City not found!
# Processing record 14 of set 10 | kiunga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=kiunga
# Processing record 15 of set 10 | meyungs
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=meyungs
# City not found!
# Processing record 16 of set 10 | matay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=matay
# Processing record 17 of set 10 | kamenka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=kamenka
# Processing record 18 of set 10 | diapaga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=diapaga
# Processing record 19 of set 10 | haapiti
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=haapiti
# Processing record 20 of set 10 | pingliang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=pingliang
# Processing record 21 of set 10 | baykit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=baykit
# Processing record 22 of set 10 | boende
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=boende
# Processing record 23 of set 10 | araouane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=araouane
# Processing record 24 of set 10 | rincon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=rincon
# Processing record 25 of set 10 | sayyan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=sayyan
# Processing record 26 of set 10 | gary
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=gary
# Processing record 27 of set 10 | meiktila
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=meiktila
# Processing record 28 of set 10 | zhengjiatun
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=zhengjiatun
# Processing record 29 of set 10 | alyangula
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=alyangula
# Processing record 30 of set 10 | campos belos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=campos belos
# Processing record 31 of set 10 | camocim
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=camocim
# Processing record 32 of set 10 | xuddur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=xuddur
# Processing record 33 of set 10 | jaru
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=jaru
# Processing record 34 of set 10 | amarante do maranhao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=amarante do maranhao
# Processing record 35 of set 10 | chengde
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=chengde
# Processing record 36 of set 10 | fuling
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=fuling
# Processing record 37 of set 10 | temaraia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=temaraia
# City not found!
# Processing record 38 of set 10 | mao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=mao
# Processing record 39 of set 10 | wajir
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=wajir
# Processing record 40 of set 10 | trinidad
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=trinidad
# Processing record 41 of set 10 | huarmey
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=huarmey
# Processing record 42 of set 10 | haines junction
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=haines junction
# Processing record 43 of set 10 | roald
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=roald
# Processing record 44 of set 10 | mamallapuram
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=mamallapuram
# Processing record 45 of set 10 | broken hill
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=broken hill
# Processing record 46 of set 10 | batemans bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=batemans bay
# Processing record 47 of set 10 | monchegorsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=monchegorsk
# Processing record 48 of set 10 | foix
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=foix
# Processing record 49 of set 10 | sobolevo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=sobolevo
# Processing record 50 of set 10 | pisco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=pisco
# Processing record 0 of set 11 | mvangue
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=mvangue
# Processing record 1 of set 11 | ayr
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=ayr
# Processing record 2 of set 11 | maceio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=maceio
# Processing record 3 of set 11 | odienne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=odienne
# Processing record 4 of set 11 | itabuna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=itabuna
# Processing record 5 of set 11 | marsh harbour
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=marsh harbour
# Processing record 6 of set 11 | malyye derbety
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=malyye derbety
# Processing record 7 of set 11 | jalu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=jalu
# Processing record 8 of set 11 | boguchany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=boguchany
# Processing record 9 of set 11 | utiroa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=utiroa
# City not found!
# Processing record 10 of set 11 | college
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=college
# Processing record 11 of set 11 | port blair
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=port blair
# Processing record 12 of set 11 | santa fe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=santa fe
# Processing record 13 of set 11 | nhulunbuy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=nhulunbuy
# Processing record 14 of set 11 | emerald
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=emerald
# Processing record 15 of set 11 | cacoal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=cacoal
# Processing record 16 of set 11 | celestun
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=celestun
# Processing record 17 of set 11 | matagami
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=matagami
# Processing record 18 of set 11 | iskitim
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=iskitim
# Processing record 19 of set 11 | comodoro rivadavia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=comodoro rivadavia
# Processing record 20 of set 11 | yola
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=yola
# Processing record 21 of set 11 | grand gaube
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=grand gaube
# Processing record 22 of set 11 | gorodishche
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=gorodishche
# Processing record 23 of set 11 | kunashak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=kunashak
# Processing record 24 of set 11 | de-kastri
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=de-kastri
# Processing record 25 of set 11 | bundi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=bundi
# Processing record 26 of set 11 | labrea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=labrea
# Processing record 27 of set 11 | cabinda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=cabinda
# Processing record 28 of set 11 | fort-shevchenko
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=fort-shevchenko
# Processing record 29 of set 11 | preobrazheniye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=preobrazheniye
# Processing record 30 of set 11 | muros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=muros
# Processing record 31 of set 11 | tapaua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=tapaua
# City not found!
# Processing record 32 of set 11 | troy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=troy
# Processing record 33 of set 11 | turayf
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=turayf
# Processing record 34 of set 11 | ekangala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=ekangala
# Processing record 35 of set 11 | los llanos de aridane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=los llanos de aridane
# Processing record 36 of set 11 | can tho
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=can tho
# Processing record 37 of set 11 | duluth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=duluth
# Processing record 38 of set 11 | ust-kuyga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=ust-kuyga
# Processing record 39 of set 11 | whitehorse
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=whitehorse
# Processing record 40 of set 11 | conceicao do mato dentro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=conceicao do mato dentro
# Processing record 41 of set 11 | qobustan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=qobustan
# Processing record 42 of set 11 | yarim
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=yarim
# Processing record 43 of set 11 | yamada
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=yamada
# Processing record 44 of set 11 | houma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=houma
# Processing record 45 of set 11 | taraz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=taraz
# Processing record 46 of set 11 | santa cruz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=santa cruz
# Processing record 47 of set 11 | tucumcari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=tucumcari
# Processing record 48 of set 11 | immenstadt
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=immenstadt
# Processing record 49 of set 11 | kuytun
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=kuytun
# Processing record 50 of set 11 | metro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=metro
# Processing record 0 of set 12 | moba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=moba
# Processing record 1 of set 12 | wageningen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=wageningen
# Processing record 2 of set 12 | northam
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=northam
# Processing record 3 of set 12 | besikduzu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=besikduzu
# Processing record 4 of set 12 | sinkat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=sinkat
# City not found!
# Processing record 5 of set 12 | lundazi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=lundazi
# Processing record 6 of set 12 | katol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=katol
# -------------------------
# Data Retrieval Complete
# -------------------------

# %%
weather_data = {
    "City": new_cities,
    "Cloudiness" : cloudiness,
    "Country" : country,
    "Date" : date,
    "Humidity" : humidity,
    "Temp": temp,
    "Lat" : lat,
    "Lng" : lng,   
    "Wind Speed" : wind
}
weather_data_df = pd.DataFrame(weather_data)
weather_data_df.count()
# Out:
# City          569
# Cloudiness    569
# Country       569
# Date          569
# Humidity      569
# Temp          569
# Lat           569
# Lng           569
# Wind Speed    569
# dtype: int64

# %%
weather_data_df
# Out:
#            City  Cloudiness Country        Date  Humidity   Temp    Lat  \
# 0     jamestown          90      US  1579886810        41  45.00  42.10
# 1        marzuq          70      YE  1579886940        80  64.47  14.40
# 2        yishui         100      CN  1579886940        63  30.16  35.78
# 3        hobart          99      AU  1579886655        55  60.80 -42.88
# 4        namibe           0      AO  1579886940        77  75.51 -15.20
# ..          ...         ...     ...         ...       ...    ...    ...
# 564  wageningen          90      NL  1579887025       100  39.00  51.97
# 565     northam          75      GB  1579887025        93  45.00  51.03
# 566   besikduzu          75      TR  1579887025        69  39.20  41.05
# 567     lundazi          37      ZM  1579887026        89  68.11 -12.29
# 568       katol           0      IN  1579887026        77  66.20  21.27
#
#         Lng  Wind Speed
# 0    -79.24        6.93
# 1     46.47        2.04
# 2    118.63        1.86
# 3    147.33        9.17
# 4     12.15       11.43
# ..      ...         ...
# 564    5.67        3.36
# 565   -4.22        5.82
# 566   39.23        6.93
# 567   33.18        7.09
# 568   78.58        4.65
#
# [569 rows x 9 columns]

# %%
weather_data_df.to_csv("../output_data/cities.csv")

# %%
weather_data_df.plot(kind='scatter', x='Lat', y = 'Temp', label = 'Temperature', c='blue', edgecolors='black')
plt.xlabel('Latitude')
plt.ylabel('Temperature (f)')
plt.legend(loc='best')
plt.title('Temperature vs Latitude')
plt.grid()
plt.savefig("../output_data/Latitude Vs Temperature.png")
plt.show()

# %%
plt.scatter(x=weather_data_df['Lat'], y = weather_data_df['Humidity'], label = 'Humidity', c='blue', edgecolors='black')
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.legend(loc='best')
plt.title('Humidity vs Latitude')
plt.grid()
plt.savefig("../output_data/Latitude Vs Humidity.png")
plt.show()

# %%
plt.scatter(x=weather_data_df['Lat'], y = weather_data_df['Cloudiness'], label = 'Cloudiness', c='blue', edgecolors='black')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.legend(loc='best')
plt.title('Cloudiness vs Latitude')
plt.grid()
plt.savefig("../output_data/Latitude Vs Cloudiness.png")
plt.show()

# %%
plt.scatter(x=weather_data_df['Lat'], y = weather_data_df['Wind Speed'], label='Wind Speed', c='blue', edgecolors='black')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.legend(loc='best')
plt.title('Wind Speed vs Latitude')
plt.grid()
plt.savefig("../output_data/Latitude Vs Wind Speed")
plt.show()

# %%
northern_df = weather_data_df.loc[weather_data_df['Lat']>=0]
northern_df
# Out:
#            City  Cloudiness Country        Date  Humidity   Temp    Lat  \
# 0     jamestown          90      US  1579886810        41  45.00  42.10
# 1        marzuq          70      YE  1579886940        80  64.47  14.40
# 2        yishui         100      CN  1579886940        63  30.16  35.78
# 6       kuching          75      MY  1579886940        88  78.80   1.55
# 7          hilo          90      US  1579886940        73  69.80  19.73
# ..          ...         ...     ...         ...       ...    ...    ...
# 563        moba          98      CN  1579887025        74  28.56  33.23
# 564  wageningen          90      NL  1579887025       100  39.00  51.97
# 565     northam          75      GB  1579887025        93  45.00  51.03
# 566   besikduzu          75      TR  1579887025        69  39.20  41.05
# 568       katol           0      IN  1579887026        77  66.20  21.27
#
#         Lng  Wind Speed
# 0    -79.24        6.93
# 1     46.47        2.04
# 2    118.63        1.86
# 6    110.33        2.24
# 7   -155.09        4.70
# ..      ...         ...
# 563  105.02        4.72
# 564    5.67        3.36
# 565   -4.22        5.82
# 566   39.23        6.93
# 568   78.58        4.65
#
# [395 rows x 9 columns]

# %%
southern_df = weather_data_df.loc[weather_data_df['Lat']<0]
southern_df
# Out:
#                          City  Cloudiness Country        Date  Humidity  \
# 3                      hobart          99      AU  1579886655        55
# 4                      namibe           0      AO  1579886940        77
# 5                punta arenas          90      CL  1579886934        87
# 8                     rikitea           0      PF  1579886941        71
# 14                     avarua          83      CK  1579886919        94
# ..                        ...         ...     ...         ...       ...
# 546                  ekangala          47      ZA  1579887023        80
# 552  conceicao do mato dentro         100      BR  1579887023        95
# 558                santa cruz          20      BO  1579887024        43
# 562                     metro         100      ID  1579886885        91
# 567                   lundazi          37      ZM  1579887026        89
#
#       Temp    Lat     Lng  Wind Speed
# 3    60.80 -42.88  147.33        9.17
# 4    75.51 -15.20   12.15       11.43
# 5    44.60 -53.15  -70.92       11.41
# 8    78.08 -23.12 -134.97       18.45
# 14   80.60 -21.21 -159.78        9.17
# ..     ...    ...     ...         ...
# 546  68.00 -25.70   28.75        1.01
# 552  69.94 -19.04  -43.42        7.85
# 558  91.40 -17.80  -63.17       11.41
# 562  77.14  -5.11  105.31        8.16
# 567  68.11 -12.29   33.18        7.09
#
# [174 rows x 9 columns]

# %% [markdown]
# # Northern Hemisphere - Temperature vs. Latitude Linear Regression

# %%
x = northern_df['Lat']
y = northern_df['Temp']
(slope, intercept, rvalues, pvalues, stderr) = stats.linregress(x, y)
regress_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x, y, label='Temperature')
plt.plot(x, regress_values, 'r-')
plt.annotate(line_eq, (10,0), fontsize=15, color='red')
plt.xlabel('Latutude')
plt.ylabel('Temperature (f)')
plt.title('Northern Hemisphere Temperature vs Latitude')
plt.legend(loc='best')
print(f"Corelation coefficient : {rvalues}")
plt.savefig("../output_data/NH temp vs lat.png")
# Out:
# Corelation coefficient : -0.8628964244508954

# %% [markdown]
# In Northern Hemisphere Temperature and lattitude has strong negative relationship, with increase in latitude temperature is decreasing,

# %% [markdown]
# # Southern Hemisphere - Temperature vs. Latitude Linear Regression

# %%
x = southern_df['Lat']
y = southern_df['Temp']
(slope, intercept, rvalues, pvalues, stderr) = stats.linregress(x, y)
regress_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x, y, label='Temperature')
plt.plot(x, regress_values, 'r-')
plt.annotate(line_eq, (-30,50), fontsize=15, color='red')
plt.xlabel('Latutude')
plt.ylabel('Temperature (f)')
plt.title('Southern Hemisphere Temperature vs Latitude')
plt.legend(loc='best')
print(f"Corelation coefficient : {rvalues}")
plt.savefig("../output_data/SH temp vs lat.png")
# Out:
# Corelation coefficient : 0.5251653396737228

# %% [markdown]
# In Southern Hemisphere Temperature and lattitude has some positive relationship, with r value is 0.52

# %% [markdown]
# # Northern Hemisphere - Humidity vs. Latitude Linear Regression

# %%
x = northern_df['Lat']
y = northern_df['Humidity']
(slope, intercept, rvalues, pvalues, stderr) = stats.linregress(x, y)
regress_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x, y, label='Humidity')
plt.plot(x, regress_values, 'r-')
plt.annotate(line_eq, (40,30), fontsize=15, color='red')
plt.xlabel('Latutude')
plt.ylabel('Humidity')
plt.title('Northern Hemisphere Humidity vs Latitude')
plt.legend(loc='best')
print(f"Corelation coefficient : {rvalues}")
plt.savefig("../output_data/NH Humidity vs Lat.png")
# Out:
# Corelation coefficient : 0.4489356839659554

# %% [markdown]
# In Northern Hemisphere there is some positive relationship between Humidity and Latitude with r value: 0.44

# %% [markdown]
# # Southern Hemisphere - Humidity vs. Latitude Linear Regression

# %%
x = southern_df['Lat']
y = southern_df['Humidity']
(slope, intercept, rvalues, pvalues, stderr) = stats.linregress(x, y)
regress_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x, y, label='Humidity')
plt.plot(x, regress_values, 'r-')
plt.annotate(line_eq, (-25,30), fontsize=15, color='red')
plt.xlabel('Latutude')
plt.ylabel('Humidity')
plt.title('Southern Hemisphere Humidity vs Latitude')
plt.legend(loc='best')
print(f"Corelation coefficient : {rvalues}")
plt.savefig("../output_data/SH Humidity vs Lat.png")
# Out:
# Corelation coefficient : 0.14182567202933086

# %% [markdown]
# In Southern Hemisphere there is no relationship between Humidity and Latitude with r value: 0.14

# %% [markdown]
# # Northern Hemisphere - Cloudiness vs. Latitude Linear Regression

# %%
x = northern_df['Lat']
y = northern_df['Cloudiness']
(slope, intercept, rvalues, pvalues, stderr) = stats.linregress(x, y)
regress_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x, y, label='Cloudiness')
plt.plot(x, regress_values, 'r-')
plt.annotate(line_eq, (40,30), fontsize=15, color='red')
plt.xlabel('Latutude')
plt.ylabel('Cloudiness')
plt.title('Northern Hemisphere Cloudiness vs Latitude')
plt.legend(loc='best')
print(f"Corelation coefficient : {rvalues}")
plt.savefig("../output_data/NH Cloudiness vs Lat.png")
# Out:
# Corelation coefficient : 0.20461334853087387

# %% [markdown]
# In Northern Hemisphere there is no relationship between Cloudiness and Latitude with r value: 0.20

# %% [markdown]
# # Southern Hemisphere - Cloudiness vs. Latitude Linear Regression

# %%
x = southern_df['Lat']
y = southern_df['Cloudiness']
(slope, intercept, rvalues, pvalues, stderr) = stats.linregress(x, y)
regress_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x, y, label='Cloudiness')
plt.plot(x, regress_values, 'r-')
plt.annotate(line_eq, (-50,20), fontsize=15, color='red')
plt.xlabel('Latutude')
plt.ylabel('Cloudiness ')
plt.title('Southern Hemisphere Cloudiness vs Latitude')
plt.legend(loc='best')
print(f"Corelation coefficient : {rvalues}")
plt.savefig("../output_data/SH Cloudiness vs Lat.png")
# Out:
# Corelation coefficient : 0.0011658735581282598

# %% [markdown]
# In Southern Hemisphere there is no relationship between Cloudiness and Latitude with r value: 0.001

# %% [markdown]
# # Northern Hemisphere - Wind Speed vs. Latitude Linear Regression

# %%
x = northern_df['Lat']
y = northern_df['Wind Speed']
(slope, intercept, rvalues, pvalues, stderr) = stats.linregress(x, y)
regress_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x, y, label='Wind Speed')
plt.plot(x, regress_values, 'r-')
plt.annotate(line_eq, (20,40), fontsize=15, color='red')
plt.xlabel('Latutude')
plt.ylabel('Wind Speed (MPH) ')
plt.title('Northern Hemisphere Wind Speed vs Latitude')
plt.legend(loc='best')
print(f"Corelation coefficient : {rvalues}")
plt.savefig("../output_data/NH WS vs lat.png")
# Out:
# Corelation coefficient : 0.1091990578063191

# %% [markdown]
# In Northern Hemisphere there is no relationship between Wind Speed and Latitude with r value: 0.11

# %% [markdown]
# # Southern Hemisphere - Wind Speed vs. Latitude Linear Regression

# %%
x = southern_df['Lat']
y = southern_df['Wind Speed']
(slope, intercept, rvalues, pvalues, stderr) = stats.linregress(x, y)
regress_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x, y, label='Wind Speed')
plt.plot(x, regress_values, 'r-')
plt.annotate(line_eq, (-30,25), fontsize=15, color='red')
plt.xlabel('Latutude')
plt.ylabel('Wind Speed (MPH) ')
plt.title('Southern Hemisphere Wind Speed vs Latitude')
plt.legend(loc='best')
print(f"Corelation coefficient : {rvalues}")
plt.savefig("../output_data/SH WS vs lat.png")
# Out:
# Corelation coefficient : -0.1762022063792785

# %% [markdown]
# In Southern Hemisphere there is no relationship between Wind Speed and Latitude with r value: -0.17.
