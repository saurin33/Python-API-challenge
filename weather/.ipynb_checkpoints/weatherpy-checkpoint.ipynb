# %%
pip install citipy
# Out:
# Collecting citipy
#   Downloading https://files.pythonhosted.org/packages/3b/d0/59721d0f3954781488aac17ee4a40412d0a3547e98bb16377a09c39a2807/citipy-0.0.5.tar.gz (557kB)
#      |████████████████████████████████| 563kB 1.2MB/s eta 0:00:01
# Collecting kdtree>=0.12 (from citipy)
#   Downloading https://files.pythonhosted.org/packages/00/3d/bd727d025b1706798aae14da3f69fc7d5a8639dc9e0eba37c7dcd43eb03e/kdtree-0.16-py2.py3-none-any.whl
# Building wheels for collected packages: citipy
#   Building wheel for citipy (setup.py) ... done
#   Created wheel for citipy: filename=citipy-0.0.5-cp37-none-any.whl size=559703 sha256=3836d786320430a077d9ae1ad77915c6dcae339cac45dbdda7364bef439a7b4b
#   Stored in directory: /Users/saurin/Library/Caches/pip/wheels/6f/07/0d/0392639cf1c10376f59decd06775c0e085ca2458c6036c1028
# Successfully built citipy
# Installing collected packages: kdtree, citipy
# Successfully installed citipy-0.0.5 kdtree-0.16
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
from api_keys import weather_api_key
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import time
from scipy.stats import stats

# %%
output_data_file = "output_data/cities.csv"
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# print(cities)
# Out:
# 586

# %%
new_cities = []
cloudiness = []
country = []
date = []
humidity = []
temp = []
lat = []
lng = []
wind = []

# %%
record_count = 0
set_count = 0
# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key 
print('------------------------')
print('Beginning Data Retrieval')
print('------------------------')

for city in cities:
    query_url = url + "&q=" + city
    # Get weather data
    response = requests.get(query_url).json()
    if record_count < 50:
        record_count += 1
    else:
        set_count += 1
        record_count = 0

    print('Processing record {} of set {} | {}'.format(record_count, set_count, city))
    print(query_url)
    try:
        cloudiness.append(response['clouds']['all'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        humidity.append(response['main']['humidity'])
        temp.append(response['main']['temp_max'])
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        wind.append(response['wind']['speed'])
        new_cities.append(city)
    except:
        print("City not found!")
        pass

print('-------------------------')
print('Data Retrieval Complete')
print('-------------------------')
# Out:
# ------------------------
# Beginning Data Retrieval
# ------------------------
# Processing record 1 of set 0 | chunskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=chunskiy
# Processing record 2 of set 0 | torbay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=torbay
# Processing record 3 of set 0 | mys shmidta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=mys shmidta
# City not found!
# Processing record 4 of set 0 | qaanaaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=qaanaaq
# Processing record 5 of set 0 | moose factory
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=moose factory
# Processing record 6 of set 0 | murdochville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=murdochville
# Processing record 7 of set 0 | vitim
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=vitim
# Processing record 8 of set 0 | sitka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=sitka
# Processing record 9 of set 0 | tiksi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=tiksi
# Processing record 10 of set 0 | ancud
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=ancud
# Processing record 11 of set 0 | vysokogornyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=vysokogornyy
# Processing record 12 of set 0 | hermanus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=hermanus
# Processing record 13 of set 0 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=ushuaia
# Processing record 14 of set 0 | porto novo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=porto novo
# Processing record 15 of set 0 | matara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=matara
# Processing record 16 of set 0 | hofn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=hofn
# Processing record 17 of set 0 | campbell river
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=campbell river
# Processing record 18 of set 0 | mar del plata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=mar del plata
# Processing record 19 of set 0 | flin flon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=flin flon
# Processing record 20 of set 0 | tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=tuktoyaktuk
# Processing record 21 of set 0 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=punta arenas
# Processing record 22 of set 0 | watsa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=watsa
# Processing record 23 of set 0 | ganzhou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=ganzhou
# Processing record 24 of set 0 | severo-kurilsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=severo-kurilsk
# Processing record 25 of set 0 | talnakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=talnakh
# Processing record 26 of set 0 | teya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=teya
# Processing record 27 of set 0 | hithadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=hithadhoo
# Processing record 28 of set 0 | dikson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=dikson
# Processing record 29 of set 0 | yellowknife
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=yellowknife
# Processing record 30 of set 0 | silvania
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=silvania
# Processing record 31 of set 0 | rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=rikitea
# Processing record 32 of set 0 | zlobin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=zlobin
# Processing record 33 of set 0 | magdagachi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=magdagachi
# Processing record 34 of set 0 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=bredasdorp
# Processing record 35 of set 0 | nizhneyansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=nizhneyansk
# City not found!
# Processing record 36 of set 0 | cape town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=cape town
# Processing record 37 of set 0 | albany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=albany
# Processing record 38 of set 0 | tezu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=tezu
# Processing record 39 of set 0 | leshukonskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=leshukonskoye
# Processing record 40 of set 0 | portland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=portland
# Processing record 41 of set 0 | sao joao da barra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=sao joao da barra
# Processing record 42 of set 0 | celestun
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=celestun
# Processing record 43 of set 0 | port-gentil
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=port-gentil
# Processing record 44 of set 0 | hobart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=hobart
# Processing record 45 of set 0 | mbandaka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=mbandaka
# Processing record 46 of set 0 | santiago
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=santiago
# Processing record 47 of set 0 | cherskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=cherskiy
# Processing record 48 of set 0 | jamestown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=jamestown
# Processing record 49 of set 0 | pisco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=pisco
# Processing record 50 of set 0 | thompson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=thompson
# Processing record 0 of set 1 | lavrentiya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=lavrentiya
# Processing record 1 of set 1 | leningradskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=leningradskiy
# Processing record 2 of set 1 | rocha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=rocha
# Processing record 3 of set 1 | tasiilaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=tasiilaq
# Processing record 4 of set 1 | mataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=mataura
# Processing record 5 of set 1 | aksarka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=aksarka
# Processing record 6 of set 1 | cidreira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=cidreira
# Processing record 7 of set 1 | mahebourg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=mahebourg
# Processing record 8 of set 1 | lake havasu city
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=lake havasu city
# Processing record 9 of set 1 | bengkulu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=bengkulu
# Processing record 10 of set 1 | atuona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=atuona
# Processing record 11 of set 1 | mareeba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=mareeba
# Processing record 12 of set 1 | gamba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=gamba
# Processing record 13 of set 1 | port alfred
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=port alfred
# Processing record 14 of set 1 | labuan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=labuan
# Processing record 15 of set 1 | avarua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=avarua
# Processing record 16 of set 1 | upernavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=upernavik
# Processing record 17 of set 1 | vuktyl
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=vuktyl
# Processing record 18 of set 1 | cananea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=cananea
# Processing record 19 of set 1 | grimari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=grimari
# City not found!
# Processing record 20 of set 1 | geraldton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=geraldton
# Processing record 21 of set 1 | kahului
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=kahului
# Processing record 22 of set 1 | clyde river
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=clyde river
# Processing record 23 of set 1 | poum
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=poum
# Processing record 24 of set 1 | kaitangata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=kaitangata
# Processing record 25 of set 1 | fort saint john
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=fort saint john
# City not found!
# Processing record 26 of set 1 | pevek
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=pevek
# Processing record 27 of set 1 | longyearbyen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=longyearbyen
# Processing record 28 of set 1 | chuy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=chuy
# Processing record 29 of set 1 | salta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=salta
# Processing record 30 of set 1 | mormugao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=mormugao
# Processing record 31 of set 1 | norman wells
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=norman wells
# Processing record 32 of set 1 | cap malheureux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=cap malheureux
# Processing record 33 of set 1 | ponta do sol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=ponta do sol
# Processing record 34 of set 1 | shache
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=shache
# Processing record 35 of set 1 | bluff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=bluff
# Processing record 36 of set 1 | dhidhdhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=dhidhdhoo
# Processing record 37 of set 1 | sambava
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=sambava
# Processing record 38 of set 1 | belushya guba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=belushya guba
# City not found!
# Processing record 39 of set 1 | barrow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=barrow
# Processing record 40 of set 1 | barentsburg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=barentsburg
# City not found!
# Processing record 41 of set 1 | san cristobal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=san cristobal
# Processing record 42 of set 1 | beipiao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=beipiao
# Processing record 43 of set 1 | harper
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=harper
# Processing record 44 of set 1 | atar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=atar
# Processing record 45 of set 1 | puerto escondido
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=puerto escondido
# Processing record 46 of set 1 | vaini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=vaini
# Processing record 47 of set 1 | laguna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=laguna
# Processing record 48 of set 1 | alyangula
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=alyangula
# Processing record 49 of set 1 | palana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=palana
# Processing record 50 of set 1 | puerto ayora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=puerto ayora
# Processing record 0 of set 2 | santa marta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=santa marta
# Processing record 1 of set 2 | imbituba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=imbituba
# Processing record 2 of set 2 | vao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=vao
# Processing record 3 of set 2 | itamarandiba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=itamarandiba
# Processing record 4 of set 2 | hit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=hit
# Processing record 5 of set 2 | seoul
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=seoul
# Processing record 6 of set 2 | necochea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=necochea
# Processing record 7 of set 2 | calvinia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=calvinia
# Processing record 8 of set 2 | alice springs
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=alice springs
# Processing record 9 of set 2 | shestakovo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=shestakovo
# Processing record 10 of set 2 | pinotepa nacional
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=pinotepa nacional
# Processing record 11 of set 2 | provideniya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=provideniya
# Processing record 12 of set 2 | lagoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=lagoa
# Processing record 13 of set 2 | arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=arraial do cabo
# Processing record 14 of set 2 | unye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=unye
# City not found!
# Processing record 15 of set 2 | chokurdakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=chokurdakh
# Processing record 16 of set 2 | hasaki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=hasaki
# Processing record 17 of set 2 | amderma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=amderma
# City not found!
# Processing record 18 of set 2 | brae
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=brae
# Processing record 19 of set 2 | skjervoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=skjervoy
# Processing record 20 of set 2 | ambon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=ambon
# Processing record 21 of set 2 | gaoual
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=gaoual
# Processing record 22 of set 2 | kuche
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=kuche
# City not found!
# Processing record 23 of set 2 | fenoarivo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=fenoarivo
# Processing record 24 of set 2 | yilan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=yilan
# Processing record 25 of set 2 | new norfolk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=new norfolk
# Processing record 26 of set 2 | saint-philippe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=saint-philippe
# Processing record 27 of set 2 | nome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=nome
# Processing record 28 of set 2 | busselton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=busselton
# Processing record 29 of set 2 | byron bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=byron bay
# Processing record 30 of set 2 | castro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=castro
# Processing record 31 of set 2 | tumannyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=tumannyy
# City not found!
# Processing record 32 of set 2 | itoman
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=itoman
# Processing record 33 of set 2 | carnarvon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=carnarvon
# Processing record 34 of set 2 | tilichiki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=tilichiki
# Processing record 35 of set 2 | taolanaro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=taolanaro
# City not found!
# Processing record 36 of set 2 | rafaela
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=rafaela
# Processing record 37 of set 2 | dien bien
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=dien bien
# City not found!
# Processing record 38 of set 2 | east london
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=east london
# Processing record 39 of set 2 | hilo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=hilo
# Processing record 40 of set 2 | manitouwadge
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=manitouwadge
# Processing record 41 of set 2 | huarmey
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=huarmey
# Processing record 42 of set 2 | thinadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=thinadhoo
# Processing record 43 of set 2 | tambura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=tambura
# Processing record 44 of set 2 | velyka bilozerka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=velyka bilozerka
# Processing record 45 of set 2 | aksehir
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=aksehir
# Processing record 46 of set 2 | naantali
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=naantali
# Processing record 47 of set 2 | gazli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=gazli
# Processing record 48 of set 2 | georgetown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=georgetown
# Processing record 49 of set 2 | pacifica
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=pacifica
# Processing record 50 of set 2 | quatre cocos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=quatre cocos
# Processing record 0 of set 3 | kamina
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=kamina
# Processing record 1 of set 3 | novokruchininskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=novokruchininskiy
# Processing record 2 of set 3 | sembe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=sembe
# Processing record 3 of set 3 | klaksvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=klaksvik
# Processing record 4 of set 3 | morondava
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=morondava
# Processing record 5 of set 3 | chagda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=chagda
# City not found!
# Processing record 6 of set 3 | burns lake
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=burns lake
# Processing record 7 of set 3 | hvolsvollur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=hvolsvollur
# Processing record 8 of set 3 | illoqqortoormiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=illoqqortoormiut
# City not found!
# Processing record 9 of set 3 | coquimbo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=coquimbo
# Processing record 10 of set 3 | khatanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=khatanga
# Processing record 11 of set 3 | vila velha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=vila velha
# Processing record 12 of set 3 | kupang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=kupang
# Processing record 13 of set 3 | tsihombe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=tsihombe
# City not found!
# Processing record 14 of set 3 | gaoua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=gaoua
# Processing record 15 of set 3 | hegang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=hegang
# Processing record 16 of set 3 | miraflores
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=miraflores
# Processing record 17 of set 3 | mut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=mut
# Processing record 18 of set 3 | shenjiamen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=shenjiamen
# Processing record 19 of set 3 | salalah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=salalah
# Processing record 20 of set 3 | vaitupu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=vaitupu
# City not found!
# Processing record 21 of set 3 | georgiyevka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=georgiyevka
# Processing record 22 of set 3 | hearst
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=hearst
# Processing record 23 of set 3 | naliya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=naliya
# Processing record 24 of set 3 | tura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=tura
# Processing record 25 of set 3 | kodiak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=kodiak
# Processing record 26 of set 3 | saldanha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=saldanha
# Processing record 27 of set 3 | ilulissat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=ilulissat
# Processing record 28 of set 3 | sentyabrskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=sentyabrskiy
# City not found!
# Processing record 29 of set 3 | suzu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=suzu
# City not found!
# Processing record 30 of set 3 | verkhoyansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=verkhoyansk
# Processing record 31 of set 3 | saskylakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=saskylakh
# Processing record 32 of set 3 | williston
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=williston
# Processing record 33 of set 3 | alofi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=alofi
# Processing record 34 of set 3 | kapaa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=kapaa
# Processing record 35 of set 3 | salinopolis
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=salinopolis
# Processing record 36 of set 3 | ostrovnoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=ostrovnoy
# Processing record 37 of set 3 | narsaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=narsaq
# Processing record 38 of set 3 | tungor
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=tungor
# Processing record 39 of set 3 | korla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=korla
# Processing record 40 of set 3 | nikolskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=nikolskoye
# Processing record 41 of set 3 | butaritari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=butaritari
# Processing record 42 of set 3 | fort nelson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=fort nelson
# Processing record 43 of set 3 | ballina
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=ballina
# Processing record 44 of set 3 | los llanos de aridane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=los llanos de aridane
# Processing record 45 of set 3 | iqaluit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=iqaluit
# Processing record 46 of set 3 | lentekhi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=lentekhi
# Processing record 47 of set 3 | norsup
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=norsup
# Processing record 48 of set 3 | awbari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=awbari
# Processing record 49 of set 3 | sabha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=sabha
# Processing record 50 of set 3 | svetlyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=svetlyy
# Processing record 0 of set 4 | baruun-urt
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=baruun-urt
# Processing record 1 of set 4 | tekirdag
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=tekirdag
# Processing record 2 of set 4 | naze
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=naze
# Processing record 3 of set 4 | pacific grove
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=pacific grove
# Processing record 4 of set 4 | okha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=okha
# Processing record 5 of set 4 | biltine
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=biltine
# Processing record 6 of set 4 | eydhafushi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=eydhafushi
# Processing record 7 of set 4 | luderitz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=luderitz
# Processing record 8 of set 4 | meyungs
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=meyungs
# City not found!
# Processing record 9 of set 4 | skerries
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=skerries
# Processing record 10 of set 4 | urla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=urla
# Processing record 11 of set 4 | homer
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=homer
# Processing record 12 of set 4 | sao filipe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=sao filipe
# Processing record 13 of set 4 | wamba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=wamba
# Processing record 14 of set 4 | vila franca do campo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=vila franca do campo
# Processing record 15 of set 4 | kavieng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=kavieng
# Processing record 16 of set 4 | deputatskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=deputatskiy
# Processing record 17 of set 4 | navrongo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=navrongo
# Processing record 18 of set 4 | tiznit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=tiznit
# Processing record 19 of set 4 | inhambane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=inhambane
# Processing record 20 of set 4 | buraydah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=buraydah
# Processing record 21 of set 4 | karauzyak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=karauzyak
# City not found!
# Processing record 22 of set 4 | dingle
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=dingle
# Processing record 23 of set 4 | broome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=broome
# Processing record 24 of set 4 | coihaique
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=coihaique
# Processing record 25 of set 4 | srednekolymsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=srednekolymsk
# Processing record 26 of set 4 | fukue
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=fukue
# Processing record 27 of set 4 | airai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=airai
# Processing record 28 of set 4 | tuatapere
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=tuatapere
# Processing record 29 of set 4 | north bend
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=north bend
# Processing record 30 of set 4 | victoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=victoria
# Processing record 31 of set 4 | luanda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=luanda
# Processing record 32 of set 4 | esmeraldas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=esmeraldas
# Processing record 33 of set 4 | samana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=samana
# Processing record 34 of set 4 | ayagoz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=ayagoz
# Processing record 35 of set 4 | dolores
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=dolores
# Processing record 36 of set 4 | joshimath
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=joshimath
# Processing record 37 of set 4 | amahai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=amahai
# Processing record 38 of set 4 | muros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=muros
# Processing record 39 of set 4 | shimoda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=shimoda
# Processing record 40 of set 4 | constitucion
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=constitucion
# Processing record 41 of set 4 | faya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=faya
# Processing record 42 of set 4 | the valley
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=the valley
# Processing record 43 of set 4 | gumla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=gumla
# Processing record 44 of set 4 | tabou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=tabou
# Processing record 45 of set 4 | kashi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=kashi
# Processing record 46 of set 4 | kedrovyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=kedrovyy
# Processing record 47 of set 4 | pathein
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=pathein
# Processing record 48 of set 4 | cabo san lucas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=cabo san lucas
# Processing record 49 of set 4 | intipuca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=intipuca
# Processing record 50 of set 4 | souillac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=souillac
# Processing record 0 of set 5 | utiroa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=utiroa
# City not found!
# Processing record 1 of set 5 | qafsah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=qafsah
# City not found!
# Processing record 2 of set 5 | palabuhanratu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=palabuhanratu
# City not found!
# Processing record 3 of set 5 | deqing
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=deqing
# Processing record 4 of set 5 | longfeng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=longfeng
# Processing record 5 of set 5 | aloleng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=aloleng
# Processing record 6 of set 5 | mullaitivu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=mullaitivu
# City not found!
# Processing record 7 of set 5 | palaikastron
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=palaikastron
# Processing record 8 of set 5 | wangqing
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=wangqing
# Processing record 9 of set 5 | ibirama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=ibirama
# Processing record 10 of set 5 | tshane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=tshane
# Processing record 11 of set 5 | sokolo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=sokolo
# Processing record 12 of set 5 | port lincoln
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=port lincoln
# Processing record 13 of set 5 | ahuimanu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=ahuimanu
# Processing record 14 of set 5 | oliveira dos brejinhos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=oliveira dos brejinhos
# Processing record 15 of set 5 | shingu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=shingu
# Processing record 16 of set 5 | seymchan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=seymchan
# Processing record 17 of set 5 | yar-sale
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=yar-sale
# Processing record 18 of set 5 | hamilton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=hamilton
# Processing record 19 of set 5 | khvatovka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=khvatovka
# Processing record 20 of set 5 | bubaque
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=bubaque
# Processing record 21 of set 5 | port elizabeth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=port elizabeth
# Processing record 22 of set 5 | jumla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=jumla
# Processing record 23 of set 5 | namibe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=namibe
# Processing record 24 of set 5 | grand-santi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=grand-santi
# Processing record 25 of set 5 | kenai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=kenai
# Processing record 26 of set 5 | lebu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=lebu
# Processing record 27 of set 5 | enumclaw
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=enumclaw
# Processing record 28 of set 5 | bilma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=bilma
# Processing record 29 of set 5 | aconibe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=aconibe
# Processing record 30 of set 5 | iquique
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=iquique
# Processing record 31 of set 5 | sabana de torres
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=sabana de torres
# Processing record 32 of set 5 | bacolod
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=bacolod
# Processing record 33 of set 5 | atambua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=atambua
# Processing record 34 of set 5 | sumbawa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=sumbawa
# City not found!
# Processing record 35 of set 5 | port blair
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=port blair
# Processing record 36 of set 5 | pak thong chai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=pak thong chai
# Processing record 37 of set 5 | grand river south east
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=grand river south east
# City not found!
# Processing record 38 of set 5 | lompoc
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=lompoc
# Processing record 39 of set 5 | lorengau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=lorengau
# Processing record 40 of set 5 | fartura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=fartura
# Processing record 41 of set 5 | rorvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=rorvik
# Processing record 42 of set 5 | tubruq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=tubruq
# City not found!
# Processing record 43 of set 5 | karoi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=karoi
# Processing record 44 of set 5 | vostok
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=vostok
# Processing record 45 of set 5 | datia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=datia
# Processing record 46 of set 5 | sakakah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=sakakah
# Processing record 47 of set 5 | walvis bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=walvis bay
# Processing record 48 of set 5 | dawlatabad
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=dawlatabad
# Processing record 49 of set 5 | martin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=martin
# Processing record 50 of set 5 | kaseda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=kaseda
# Processing record 0 of set 6 | dunedin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=dunedin
# Processing record 1 of set 6 | komsomolskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=komsomolskiy
# Processing record 2 of set 6 | avera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=avera
# Processing record 3 of set 6 | staryy nadym
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=staryy nadym
# Processing record 4 of set 6 | vestmanna
# ...
# Processing record 25 of set 9 | severnoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=severnoye
# Processing record 26 of set 9 | saryozek
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=saryozek
# Processing record 27 of set 9 | dingzhou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=dingzhou
# Processing record 28 of set 9 | whitehorse
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=whitehorse
# Processing record 29 of set 9 | lagunas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=lagunas
# Processing record 30 of set 9 | haikou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=haikou
# Processing record 31 of set 9 | princeton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=princeton
# Processing record 32 of set 9 | graaff-reinet
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=graaff-reinet
# Processing record 33 of set 9 | anadyr
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=anadyr
# Processing record 34 of set 9 | krasnoselkup
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=krasnoselkup
# Processing record 35 of set 9 | shubarkuduk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=shubarkuduk
# Processing record 36 of set 9 | prenzlau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=prenzlau
# Processing record 37 of set 9 | altay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=altay
# Processing record 38 of set 9 | ust-bolsheretsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=ust-bolsheretsk
# City not found!
# Processing record 39 of set 9 | khani
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=khani
# Processing record 40 of set 9 | hemsedal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=hemsedal
# Processing record 41 of set 9 | goma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=goma
# Processing record 42 of set 9 | wahran
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=wahran
# City not found!
# Processing record 43 of set 9 | menongue
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=menongue
# Processing record 44 of set 9 | aitape
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=aitape
# Processing record 45 of set 9 | whitecourt
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=whitecourt
# Processing record 46 of set 9 | turka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=turka
# Processing record 47 of set 9 | tongliao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=tongliao
# Processing record 48 of set 9 | russell
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=russell
# Processing record 49 of set 9 | nguiu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=nguiu
# City not found!
# Processing record 50 of set 9 | allen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=allen
# Processing record 0 of set 10 | iranshahr
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=iranshahr
# Processing record 1 of set 10 | hammerfest
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=hammerfest
# Processing record 2 of set 10 | callaway
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=callaway
# Processing record 3 of set 10 | sayula
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=sayula
# Processing record 4 of set 10 | corralillo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=corralillo
# Processing record 5 of set 10 | mount gambier
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=mount gambier
# Processing record 6 of set 10 | hermosillo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=hermosillo
# Processing record 7 of set 10 | rungata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=rungata
# City not found!
# Processing record 8 of set 10 | nyurba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=nyurba
# Processing record 9 of set 10 | ugoofaaru
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=ugoofaaru
# Processing record 10 of set 10 | high rock
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=high rock
# Processing record 11 of set 10 | kalmunai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=kalmunai
# Processing record 12 of set 10 | northam
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=northam
# Processing record 13 of set 10 | sokoni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=sokoni
# Processing record 14 of set 10 | senanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=senanga
# Processing record 15 of set 10 | sumbe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=sumbe
# Processing record 16 of set 10 | haimen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=haimen
# Processing record 17 of set 10 | yaan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=yaan
# Processing record 18 of set 10 | mtwara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=mtwara
# Processing record 19 of set 10 | kribi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=kribi
# Processing record 20 of set 10 | gwanda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=gwanda
# Processing record 21 of set 10 | sibolga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=sibolga
# Processing record 22 of set 10 | sisimiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=sisimiut
# Processing record 23 of set 10 | zhoucheng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=zhoucheng
# Processing record 24 of set 10 | havelock
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=havelock
# Processing record 25 of set 10 | yola
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=yola
# Processing record 26 of set 10 | westport
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=westport
# Processing record 27 of set 10 | lypova dolyna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=lypova dolyna
# Processing record 28 of set 10 | gravdal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=gravdal
# Processing record 29 of set 10 | semnan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=semnan
# Processing record 30 of set 10 | erenhot
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=erenhot
# Processing record 31 of set 10 | linhares
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=linhares
# Processing record 32 of set 10 | gobabis
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=gobabis
# Processing record 33 of set 10 | yambio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=yambio
# Processing record 34 of set 10 | tete
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=tete
# Processing record 35 of set 10 | sistranda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=sistranda
# Processing record 36 of set 10 | cabedelo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=cabedelo
# Processing record 37 of set 10 | akyab
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=akyab
# Processing record 38 of set 10 | cabatuan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=cabatuan
# Processing record 39 of set 10 | marienburg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=marienburg
# Processing record 40 of set 10 | burnie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=burnie
# Processing record 41 of set 10 | lebyazhye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=lebyazhye
# Processing record 42 of set 10 | beni suef
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=beni suef
# Processing record 43 of set 10 | prainha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=prainha
# Processing record 44 of set 10 | yatou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=yatou
# Processing record 45 of set 10 | ippy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=ippy
# Processing record 46 of set 10 | meulaboh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=meulaboh
# Processing record 47 of set 10 | mercedes
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=mercedes
# Processing record 48 of set 10 | yabrud
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=yabrud
# Processing record 49 of set 10 | college
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=college
# Processing record 50 of set 10 | axim
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=axim
# Processing record 0 of set 11 | raudeberg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=raudeberg
# Processing record 1 of set 11 | rio gallegos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=rio gallegos
# Processing record 2 of set 11 | lesnoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=lesnoy
# Processing record 3 of set 11 | bay city
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=bay city
# Processing record 4 of set 11 | priiskovyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=priiskovyy
# Processing record 5 of set 11 | acajutla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=acajutla
# Processing record 6 of set 11 | sao gabriel da cachoeira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=sao gabriel da cachoeira
# Processing record 7 of set 11 | yerbogachen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=yerbogachen
# Processing record 8 of set 11 | tessalit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=tessalit
# Processing record 9 of set 11 | shaunavon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=shaunavon
# Processing record 10 of set 11 | amaigbo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=amaigbo
# Processing record 11 of set 11 | buluang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=buluang
# Processing record 12 of set 11 | alexandria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=alexandria
# Processing record 13 of set 11 | havre-saint-pierre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=havre-saint-pierre
# Processing record 14 of set 11 | cape coast
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=cape coast
# Processing record 15 of set 11 | mazagao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=mazagao
# Processing record 16 of set 11 | pastos bons
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=pastos bons
# Processing record 17 of set 11 | mattawa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=mattawa
# Processing record 18 of set 11 | metz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=metz
# Processing record 19 of set 11 | port macquarie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=port macquarie
# Processing record 20 of set 11 | morehead
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=morehead
# Processing record 21 of set 11 | sindor
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=sindor
# Processing record 22 of set 11 | inuvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=inuvik
# Processing record 23 of set 11 | bathsheba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=bathsheba
# Processing record 24 of set 11 | kamenica
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=kamenica
# Processing record 25 of set 11 | udachnyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=udachnyy
# -------------------------
# Data Retrieval Complete
# -------------------------

# %%
weather_data = {
    "City": new_cities,
    "Cloudiness" : cloudiness,
    "Country" : country,
    "Date" : date,
    "Humidity" : humidity,
    "Temp": temp,
    "Lat" : lat,
    "Lng" : lng,   
    "Wind Speed" : wind
}
weather_data_df = pd.DataFrame(weather_data)
weather_data_df.count()
# Out:
# City          542
# Cloudiness    542
# Country       542
# Date          542
# Humidity      542
# Temp          542
# Lat           542
# Lng           542
# Wind Speed    542
# dtype: int64

# %%
weather_data_df
# Out:
#               City  Cloudiness Country        Date  Humidity   Temp    Lat  \
# 0         chunskiy          99      RU  1580229963        91   6.96  56.08
# 1           torbay          90      CA  1580229963        95  34.00  47.67
# 2          qaanaaq          96      GL  1580229964        80 -11.74  77.48
# 3    moose factory          90      CA  1580229964        84   3.20  51.26
# 4     murdochville         100      CA  1580229964        89  11.86  48.96
# ..             ...         ...     ...         ...       ...    ...    ...
# 537         sindor          98      RU  1580230050        97  -4.43  62.86
# 538         inuvik          40      CA  1580230050        67 -22.00  68.35
# 539      bathsheba          75      BB  1580230050        70  84.20  13.22
# 540       kamenica          90      DE  1580229887        75  41.00  50.83
# 541       udachnyy         100      RU  1580230051        91   3.42  66.42
#
#         Lng  Wind Speed
# 0     99.63        1.32
# 1    -52.73        5.82
# 2    -69.36        2.01
# 3    -80.61        8.05
# 4    -65.50        6.58
# ..      ...         ...
# 537   51.89        5.12
# 538 -133.72        2.24
# 539  -59.52       14.99
# 540   12.92       19.46
# 541  112.40       12.28
#
# [542 rows x 9 columns]

# %%
weather_data_df.to_csv("../output_data/cities.csv")

# %%
weather_data_df.plot(kind='scatter', x='Lat', y = 'Temp', label = 'Temperature', c='blue', edgecolors='black')
plt.xlabel('Latitude')
plt.ylabel('Temperature (f)')
plt.legend(loc='best')
plt.title('Temperature vs Latitude')
plt.grid()
plt.savefig("../output_data/Latitude Vs Temperature.png")
plt.show()

# %%
plt.scatter(x=weather_data_df['Lat'], y = weather_data_df['Humidity'], label = 'Humidity', c='blue', edgecolors='black')
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.legend(loc='best')
plt.title('Humidity vs Latitude')
plt.grid()
plt.savefig("../output_data/Latitude Vs Humidity.png")
plt.show()

# %%
plt.scatter(x=weather_data_df['Lat'], y = weather_data_df['Cloudiness'], label = 'Cloudiness', c='blue', edgecolors='black')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.legend(loc='best')
plt.title('Cloudiness vs Latitude')
plt.grid()
plt.savefig("../output_data/Latitude Vs Cloudiness.png")
plt.show()

# %%
plt.scatter(x=weather_data_df['Lat'], y = weather_data_df['Wind Speed'], label='Wind Speed', c='blue', edgecolors='black')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.legend(loc='best')
plt.title('Wind Speed vs Latitude')
plt.grid()
plt.savefig("../output_data/Latitude Vs Wind Speed")
plt.show()

# %%
northern_df = weather_data_df.loc[weather_data_df['Lat']>=0]
northern_df
# Out:
#               City  Cloudiness Country        Date  Humidity   Temp    Lat  \
# 0         chunskiy          99      RU  1580229963        91   6.96  56.08
# 1           torbay          90      CA  1580229963        95  34.00  47.67
# 2          qaanaaq          96      GL  1580229964        80 -11.74  77.48
# 3    moose factory          90      CA  1580229964        84   3.20  51.26
# 4     murdochville         100      CA  1580229964        89  11.86  48.96
# ..             ...         ...     ...         ...       ...    ...    ...
# 537         sindor          98      RU  1580230050        97  -4.43  62.86
# 538         inuvik          40      CA  1580230050        67 -22.00  68.35
# 539      bathsheba          75      BB  1580230050        70  84.20  13.22
# 540       kamenica          90      DE  1580229887        75  41.00  50.83
# 541       udachnyy         100      RU  1580230051        91   3.42  66.42
#
#         Lng  Wind Speed
# 0     99.63        1.32
# 1    -52.73        5.82
# 2    -69.36        2.01
# 3    -80.61        8.05
# 4    -65.50        6.58
# ..      ...         ...
# 537   51.89        5.12
# 538 -133.72        2.24
# 539  -59.52       14.99
# 540   12.92       19.46
# 541  112.40       12.28
#
# [377 rows x 9 columns]

# %%
southern_df = weather_data_df.loc[weather_data_df['Lat']<0]
southern_df
# Out:
#                          City  Cloudiness Country        Date  Humidity  \
# 8                       ancud          75      CL  1580229967        42
# 10                   hermanus           3      ZA  1580229967        83
# 11                    ushuaia          75      AR  1580229715        81
# 16              mar del plata          11      AR  1580229968        33
# 19               punta arenas          20      CL  1580229841        50
# ..                        ...         ...     ...         ...       ...
# 517              rio gallegos          40      AR  1580230047        30
# 522  sao gabriel da cachoeira          75      BR  1580230037        94
# 531                   mazagao          75      BR  1580230049        70
# 532               pastos bons          66      BR  1580230049        85
# 535            port macquarie          42      AU  1580230050        78
#
#       Temp    Lat     Lng  Wind Speed
# 8    62.60 -41.87  -73.82       12.75
# 10   73.00 -34.42   19.23        8.99
# 11   48.20 -54.80  -68.30       27.51
# 16   84.99 -38.00  -57.56        4.00
# 19   53.60 -53.15  -70.92       33.33
# ..     ...    ...     ...         ...
# 517  59.00 -51.62  -69.22       35.57
# 522  82.40  -0.13  -67.09        5.82
# 531  91.40  -0.12  -51.29        5.82
# 532  81.66  -6.60  -44.08        2.68
# 535  77.00 -31.43  152.92        6.93
#
# [165 rows x 9 columns]

# %% [markdown]
# # Northern Hemisphere - Temperature vs. Latitude Linear Regression

# %%
x = northern_df['Lat']
y = northern_df['Temp']
(slope, intercept, rvalues, pvalues, stderr) = stats.linregress(x, y)
regress_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x, y, label='Temperature')
plt.plot(x, regress_values, 'r-')
plt.annotate(line_eq, (10,0), fontsize=15, color='red')
plt.xlabel('Latutude')
plt.ylabel('Temperature (f)')
plt.title('Northern Hemisphere Temperature vs Latitude')
plt.legend(loc='best')
print(f"Corelation coefficient : {rvalues}")
plt.savefig("../output_data/NH temp vs lat.png")
# Out:
# Corelation coefficient : -0.891772271325204

# %% [markdown]
# In Northern Hemisphere Temperature and lattitude has strong negative relationship, with increase in latitude temperature is decreasing,

# %% [markdown]
# # Southern Hemisphere - Temperature vs. Latitude Linear Regression

# %%
x = southern_df['Lat']
y = southern_df['Temp']
(slope, intercept, rvalues, pvalues, stderr) = stats.linregress(x, y)
regress_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x, y, label='Temperature')
plt.plot(x, regress_values, 'r-')
plt.annotate(line_eq, (-30,50), fontsize=15, color='red')
plt.xlabel('Latutude')
plt.ylabel('Temperature (f)')
plt.title('Southern Hemisphere Temperature vs Latitude')
plt.legend(loc='best')
print(f"Corelation coefficient : {rvalues}")
plt.savefig("../output_data/SH temp vs lat.png")
# Out:
# Corelation coefficient : 0.5096291899323264

# %% [markdown]
# In Southern Hemisphere Temperature and lattitude has some positive relationship, with r value is 0.52

# %% [markdown]
# # Northern Hemisphere - Humidity vs. Latitude Linear Regression

# %%
x = northern_df['Lat']
y = northern_df['Humidity']
(slope, intercept, rvalues, pvalues, stderr) = stats.linregress(x, y)
regress_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x, y, label='Humidity')
plt.plot(x, regress_values, 'r-')
plt.annotate(line_eq, (40,30), fontsize=15, color='red')
plt.xlabel('Latutude')
plt.ylabel('Humidity')
plt.title('Northern Hemisphere Humidity vs Latitude')
plt.legend(loc='best')
print(f"Corelation coefficient : {rvalues}")
plt.savefig("../output_data/NH Humidity vs Lat.png")
# Out:
# Corelation coefficient : 0.4268006759748029

# %% [markdown]
# In Northern Hemisphere there is some positive relationship between Humidity and Latitude with r value: 0.44

# %% [markdown]
# # Southern Hemisphere - Humidity vs. Latitude Linear Regression

# %%
x = southern_df['Lat']
y = southern_df['Humidity']
(slope, intercept, rvalues, pvalues, stderr) = stats.linregress(x, y)
regress_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x, y, label='Humidity')
plt.plot(x, regress_values, 'r-')
plt.annotate(line_eq, (-25,30), fontsize=15, color='red')
plt.xlabel('Latutude')
plt.ylabel('Humidity')
plt.title('Southern Hemisphere Humidity vs Latitude')
plt.legend(loc='best')
print(f"Corelation coefficient : {rvalues}")
plt.savefig("../output_data/SH Humidity vs Lat.png")
# Out:
# Corelation coefficient : 0.26974118444953366

# %% [markdown]
# In Southern Hemisphere there is no relationship between Humidity and Latitude with r value: 0.14

# %% [markdown]
# # Northern Hemisphere - Cloudiness vs. Latitude Linear Regression

# %%
x = northern_df['Lat']
y = northern_df['Cloudiness']
(slope, intercept, rvalues, pvalues, stderr) = stats.linregress(x, y)
regress_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x, y, label='Cloudiness')
plt.plot(x, regress_values, 'r-')
plt.annotate(line_eq, (40,30), fontsize=15, color='red')
plt.xlabel('Latutude')
plt.ylabel('Cloudiness')
plt.title('Northern Hemisphere Cloudiness vs Latitude')
plt.legend(loc='best')
print(f"Corelation coefficient : {rvalues}")
plt.savefig("../output_data/NH Cloudiness vs Lat.png")
# Out:
# Corelation coefficient : 0.19019129258102735

# %% [markdown]
# In Northern Hemisphere there is no relationship between Cloudiness and Latitude with r value: 0.20

# %% [markdown]
# # Southern Hemisphere - Cloudiness vs. Latitude Linear Regression

# %%
x = southern_df['Lat']
y = southern_df['Cloudiness']
(slope, intercept, rvalues, pvalues, stderr) = stats.linregress(x, y)
regress_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x, y, label='Cloudiness')
plt.plot(x, regress_values, 'r-')
plt.annotate(line_eq, (-50,20), fontsize=15, color='red')
plt.xlabel('Latutude')
plt.ylabel('Cloudiness ')
plt.title('Southern Hemisphere Cloudiness vs Latitude')
plt.legend(loc='best')
print(f"Corelation coefficient : {rvalues}")
plt.savefig("../output_data/SH Cloudiness vs Lat.png")
# Out:
# Corelation coefficient : 0.2722930815891286

# %% [markdown]
# In Southern Hemisphere there is no relationship between Cloudiness and Latitude with r value: 0.001

# %% [markdown]
# # Northern Hemisphere - Wind Speed vs. Latitude Linear Regression

# %%
x = northern_df['Lat']
y = northern_df['Wind Speed']
(slope, intercept, rvalues, pvalues, stderr) = stats.linregress(x, y)
regress_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x, y, label='Wind Speed')
plt.plot(x, regress_values, 'r-')
plt.annotate(line_eq, (20,40), fontsize=15, color='red')
plt.xlabel('Latutude')
plt.ylabel('Wind Speed (MPH) ')
plt.title('Northern Hemisphere Wind Speed vs Latitude')
plt.legend(loc='best')
print(f"Corelation coefficient : {rvalues}")
plt.savefig("../output_data/NH WS vs lat.png")
# Out:
# Corelation coefficient : 0.1116109431859038

# %% [markdown]
# In Northern Hemisphere there is no relationship between Wind Speed and Latitude with r value: 0.11

# %% [markdown]
# # Southern Hemisphere - Wind Speed vs. Latitude Linear Regression

# %%
x = southern_df['Lat']
y = southern_df['Wind Speed']
(slope, intercept, rvalues, pvalues, stderr) = stats.linregress(x, y)
regress_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x, y, label='Wind Speed')
plt.plot(x, regress_values, 'r-')
plt.annotate(line_eq, (-30,25), fontsize=15, color='red')
plt.xlabel('Latutude')
plt.ylabel('Wind Speed (MPH) ')
plt.title('Southern Hemisphere Wind Speed vs Latitude')
plt.legend(loc='best')
print(f"Corelation coefficient : {rvalues}")
plt.savefig("../output_data/SH WS vs lat.png")
# Out:
# Corelation coefficient : -0.2625146633095336

# %% [markdown]
# In Southern Hemisphere there is no relationship between Wind Speed and Latitude with r value: -0.17.
