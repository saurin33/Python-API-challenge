# %%
pip install citipy
# Out:
# Collecting citipy
#   Downloading https://files.pythonhosted.org/packages/3b/d0/59721d0f3954781488aac17ee4a40412d0a3547e98bb16377a09c39a2807/citipy-0.0.5.tar.gz (557kB)
#      |████████████████████████████████| 563kB 1.2MB/s eta 0:00:01
# Collecting kdtree>=0.12 (from citipy)
#   Downloading https://files.pythonhosted.org/packages/00/3d/bd727d025b1706798aae14da3f69fc7d5a8639dc9e0eba37c7dcd43eb03e/kdtree-0.16-py2.py3-none-any.whl
# Building wheels for collected packages: citipy
#   Building wheel for citipy (setup.py) ... done
#   Created wheel for citipy: filename=citipy-0.0.5-cp37-none-any.whl size=559703 sha256=3836d786320430a077d9ae1ad77915c6dcae339cac45dbdda7364bef439a7b4b
#   Stored in directory: /Users/saurin/Library/Caches/pip/wheels/6f/07/0d/0392639cf1c10376f59decd06775c0e085ca2458c6036c1028
# Successfully built citipy
# Installing collected packages: kdtree, citipy
# Successfully installed citipy-0.0.5 kdtree-0.16
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
from api_keys import weather_api_key
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import time
from scipy.stats import stats

# %%
output_data_file = "output_data/cities.csv"
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# print(cities)
# Out:
# 622

# %%
new_cities = []
cloudiness = []
country = []
date = []
humidity = []
temp = []
lat = []
lng = []
wind = []

# %%
record_count = 0
set_count = 0
# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key 
print('------------------------')
print('Beginning Data Retrieval')
print('------------------------')

for city in cities:
    query_url = url + "&q=" + city
    # Get weather data
    response = requests.get(query_url).json()
    if record_count < 50:
        record_count += 1
    else:
        set_count += 1
        record_count = 0

    print('Processing record {} of set {} | {}'.format(record_count, set_count, city))
    print(query_url)
    try:
        cloudiness.append(response['clouds']['all'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        humidity.append(response['main']['humidity'])
        temp.append(response['main']['temp_max'])
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        wind.append(response['wind']['speed'])
        new_cities.append(city)
    except:
        print("City not found!")
        pass

print('-------------------------')
print('Data Retrieval Complete')
print('-------------------------')
# Out:
# ------------------------
# Beginning Data Retrieval
# ------------------------
# Processing record 1 of set 0 | yellowknife
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=yellowknife
# Processing record 2 of set 0 | kodiak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=kodiak
# Processing record 3 of set 0 | georgetown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=georgetown
# Processing record 4 of set 0 | sao sebastiao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=sao sebastiao
# Processing record 5 of set 0 | san cristobal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=san cristobal
# Processing record 6 of set 0 | kaseda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=kaseda
# Processing record 7 of set 0 | tsienyane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=tsienyane
# City not found!
# Processing record 8 of set 0 | puerto ayora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=puerto ayora
# Processing record 9 of set 0 | mayor pablo lagerenza
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=mayor pablo lagerenza
# Processing record 10 of set 0 | ahipara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=ahipara
# Processing record 11 of set 0 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=punta arenas
# Processing record 12 of set 0 | saint-louis
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=saint-louis
# Processing record 13 of set 0 | longyearbyen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=longyearbyen
# Processing record 14 of set 0 | taolanaro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=taolanaro
# City not found!
# Processing record 15 of set 0 | chilca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=chilca
# Processing record 16 of set 0 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=ushuaia
# Processing record 17 of set 0 | klaksvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=klaksvik
# Processing record 18 of set 0 | sorland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=sorland
# Processing record 19 of set 0 | yar-sale
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=yar-sale
# Processing record 20 of set 0 | wilmington
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=wilmington
# Processing record 21 of set 0 | mehamn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=mehamn
# Processing record 22 of set 0 | busselton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=busselton
# Processing record 23 of set 0 | tucumcari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=tucumcari
# Processing record 24 of set 0 | whitehorse
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=whitehorse
# Processing record 25 of set 0 | illoqqortoormiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=illoqqortoormiut
# City not found!
# Processing record 26 of set 0 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=bredasdorp
# Processing record 27 of set 0 | dudinka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=dudinka
# Processing record 28 of set 0 | qiyang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=qiyang
# Processing record 29 of set 0 | hlukhiv
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=hlukhiv
# Processing record 30 of set 0 | avarua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=avarua
# Processing record 31 of set 0 | olafsvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=olafsvik
# Processing record 32 of set 0 | butaritari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=butaritari
# Processing record 33 of set 0 | rassvet
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=rassvet
# Processing record 34 of set 0 | mecca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=mecca
# Processing record 35 of set 0 | rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=rikitea
# Processing record 36 of set 0 | clyde river
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=clyde river
# Processing record 37 of set 0 | la sarre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=la sarre
# Processing record 38 of set 0 | hermanus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=hermanus
# Processing record 39 of set 0 | ewa beach
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=ewa beach
# Processing record 40 of set 0 | vaini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=vaini
# Processing record 41 of set 0 | touros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=touros
# Processing record 42 of set 0 | baykalsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=baykalsk
# Processing record 43 of set 0 | sentyabrskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=sentyabrskiy
# City not found!
# Processing record 44 of set 0 | alyangula
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=alyangula
# Processing record 45 of set 0 | grand river south east
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=grand river south east
# City not found!
# Processing record 46 of set 0 | mataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=mataura
# Processing record 47 of set 0 | albany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=albany
# Processing record 48 of set 0 | nikolskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=nikolskoye
# Processing record 49 of set 0 | saldanha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=saldanha
# Processing record 50 of set 0 | khatanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=khatanga
# Processing record 0 of set 1 | cape town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=cape town
# Processing record 1 of set 1 | meyungs
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=meyungs
# City not found!
# Processing record 2 of set 1 | maloshuyka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=maloshuyka
# City not found!
# Processing record 3 of set 1 | iqaluit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=iqaluit
# Processing record 4 of set 1 | fairbanks
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=fairbanks
# Processing record 5 of set 1 | agaro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=agaro
# Processing record 6 of set 1 | morristown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=morristown
# Processing record 7 of set 1 | castro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=castro
# Processing record 8 of set 1 | bluff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=bluff
# Processing record 9 of set 1 | saskylakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=saskylakh
# Processing record 10 of set 1 | mareeba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=mareeba
# Processing record 11 of set 1 | airai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=airai
# Processing record 12 of set 1 | atuona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=atuona
# Processing record 13 of set 1 | starkville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=starkville
# Processing record 14 of set 1 | qarchi gak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=qarchi gak
# Processing record 15 of set 1 | insar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=insar
# Processing record 16 of set 1 | mar del plata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=mar del plata
# Processing record 17 of set 1 | las guacamayas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=las guacamayas
# Processing record 18 of set 1 | faanui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=faanui
# Processing record 19 of set 1 | lashio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=lashio
# Processing record 20 of set 1 | luderitz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=luderitz
# Processing record 21 of set 1 | erzin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=erzin
# Processing record 22 of set 1 | hobart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=hobart
# Processing record 23 of set 1 | sertaozinho
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=sertaozinho
# Processing record 24 of set 1 | matara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=matara
# Processing record 25 of set 1 | barrow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=barrow
# Processing record 26 of set 1 | san isidro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=san isidro
# Processing record 27 of set 1 | yulara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=yulara
# Processing record 28 of set 1 | bethel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=bethel
# Processing record 29 of set 1 | thompson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=thompson
# Processing record 30 of set 1 | severo-kurilsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=severo-kurilsk
# Processing record 31 of set 1 | te anau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=te anau
# Processing record 32 of set 1 | barentsburg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=barentsburg
# City not found!
# Processing record 33 of set 1 | upernavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=upernavik
# Processing record 34 of set 1 | viedma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=viedma
# Processing record 35 of set 1 | qui nhon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=qui nhon
# Processing record 36 of set 1 | gangapur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=gangapur
# Processing record 37 of set 1 | hilo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=hilo
# Processing record 38 of set 1 | nemuro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=nemuro
# Processing record 39 of set 1 | evanston
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=evanston
# Processing record 40 of set 1 | qaanaaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=qaanaaq
# Processing record 41 of set 1 | east london
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=east london
# Processing record 42 of set 1 | pangnirtung
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=pangnirtung
# Processing record 43 of set 1 | arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=arraial do cabo
# Processing record 44 of set 1 | torbay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=torbay
# Processing record 45 of set 1 | banda aceh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=banda aceh
# Processing record 46 of set 1 | portree
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=portree
# Processing record 47 of set 1 | katsuura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=katsuura
# Processing record 48 of set 1 | athabasca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=athabasca
# Processing record 49 of set 1 | guerrero negro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=guerrero negro
# Processing record 50 of set 1 | guadalupe y calvo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=guadalupe y calvo
# Processing record 0 of set 2 | sitka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=sitka
# Processing record 1 of set 2 | mahibadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=mahibadhoo
# Processing record 2 of set 2 | cumaribo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=cumaribo
# City not found!
# Processing record 3 of set 2 | berlevag
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=berlevag
# Processing record 4 of set 2 | rio grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=rio grande
# Processing record 5 of set 2 | tiksi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=tiksi
# Processing record 6 of set 2 | san ramon de la nueva oran
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=san ramon de la nueva oran
# Processing record 7 of set 2 | guane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=guane
# Processing record 8 of set 2 | kapaa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=kapaa
# Processing record 9 of set 2 | borazjan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=borazjan
# Processing record 10 of set 2 | rognan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=rognan
# Processing record 11 of set 2 | ishigaki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=ishigaki
# Processing record 12 of set 2 | lavrentiya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=lavrentiya
# Processing record 13 of set 2 | sisimiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=sisimiut
# Processing record 14 of set 2 | jertih
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=jertih
# Processing record 15 of set 2 | katherine
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=katherine
# Processing record 16 of set 2 | sao filipe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=sao filipe
# Processing record 17 of set 2 | nova londrina
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=nova londrina
# Processing record 18 of set 2 | raudeberg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=raudeberg
# Processing record 19 of set 2 | chuka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=chuka
# Processing record 20 of set 2 | mahebourg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=mahebourg
# Processing record 21 of set 2 | vanimo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=vanimo
# Processing record 22 of set 2 | meadow lake
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=meadow lake
# Processing record 23 of set 2 | maceio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=maceio
# Processing record 24 of set 2 | kavaratti
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=kavaratti
# Processing record 25 of set 2 | supaul
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=supaul
# Processing record 26 of set 2 | menongue
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=menongue
# Processing record 27 of set 2 | havre-saint-pierre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=havre-saint-pierre
# Processing record 28 of set 2 | paradwip
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=paradwip
# City not found!
# Processing record 29 of set 2 | vostochnyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=vostochnyy
# Processing record 30 of set 2 | kirkenaer
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=kirkenaer
# Processing record 31 of set 2 | pecos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=pecos
# Processing record 32 of set 2 | podsineye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=podsineye
# Processing record 33 of set 2 | esperance
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=esperance
# Processing record 34 of set 2 | nizhneyansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=nizhneyansk
# City not found!
# Processing record 35 of set 2 | amderma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=amderma
# City not found!
# Processing record 36 of set 2 | kushiro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=kushiro
# Processing record 37 of set 2 | bargal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=bargal
# City not found!
# Processing record 38 of set 2 | palana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=palana
# Processing record 39 of set 2 | pacifica
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=pacifica
# Processing record 40 of set 2 | buin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=buin
# Processing record 41 of set 2 | salto
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=salto
# Processing record 42 of set 2 | cidreira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=cidreira
# Processing record 43 of set 2 | lebu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=lebu
# Processing record 44 of set 2 | baruun-urt
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=baruun-urt
# Processing record 45 of set 2 | provideniya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=provideniya
# Processing record 46 of set 2 | egvekinot
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=egvekinot
# Processing record 47 of set 2 | ambilobe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=ambilobe
# Processing record 48 of set 2 | mys shmidta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=mys shmidta
# City not found!
# Processing record 49 of set 2 | portland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=portland
# Processing record 50 of set 2 | gogrial
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=gogrial
# Processing record 0 of set 3 | tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=tuktoyaktuk
# Processing record 1 of set 3 | codrington
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=codrington
# Processing record 2 of set 3 | saint george
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=saint george
# Processing record 3 of set 3 | hithadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=hithadhoo
# Processing record 4 of set 3 | srednekolymsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=srednekolymsk
# Processing record 5 of set 3 | waipawa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=waipawa
# Processing record 6 of set 3 | belushya guba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=belushya guba
# City not found!
# Processing record 7 of set 3 | richards bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=richards bay
# Processing record 8 of set 3 | ballina
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=ballina
# Processing record 9 of set 3 | moyale
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=moyale
# Processing record 10 of set 3 | port alfred
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=port alfred
# Processing record 11 of set 3 | fortuna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=fortuna
# Processing record 12 of set 3 | vangaindrano
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=vangaindrano
# Processing record 13 of set 3 | urdzhar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=urdzhar
# City not found!
# Processing record 14 of set 3 | vardo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=vardo
# Processing record 15 of set 3 | ust-barguzin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=ust-barguzin
# Processing record 16 of set 3 | carnarvon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=carnarvon
# Processing record 17 of set 3 | grindavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=grindavik
# Processing record 18 of set 3 | lagoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=lagoa
# Processing record 19 of set 3 | tawzar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=tawzar
# City not found!
# Processing record 20 of set 3 | jalu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=jalu
# Processing record 21 of set 3 | sikeston
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=sikeston
# Processing record 22 of set 3 | souillac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=souillac
# Processing record 23 of set 3 | yerbogachen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=yerbogachen
# Processing record 24 of set 3 | nenjiang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=nenjiang
# Processing record 25 of set 3 | tawkar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=tawkar
# City not found!
# Processing record 26 of set 3 | dikson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=dikson
# Processing record 27 of set 3 | kathmandu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=kathmandu
# Processing record 28 of set 3 | deputatskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=deputatskiy
# Processing record 29 of set 3 | albury
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=albury
# Processing record 30 of set 3 | north vanlaiphai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=north vanlaiphai
# Processing record 31 of set 3 | siderno
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=siderno
# Processing record 32 of set 3 | rafaela
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=rafaela
# Processing record 33 of set 3 | ratnagiri
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=ratnagiri
# Processing record 34 of set 3 | beringovskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=beringovskiy
# Processing record 35 of set 3 | satitoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=satitoa
# City not found!
# Processing record 36 of set 3 | vaitupu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=vaitupu
# City not found!
# Processing record 37 of set 3 | westpunt
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=westpunt
# City not found!
# Processing record 38 of set 3 | phanat nikhom
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=phanat nikhom
# Processing record 39 of set 3 | attawapiskat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=attawapiskat
# City not found!
# Processing record 40 of set 3 | alofi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=alofi
# Processing record 41 of set 3 | alenquer
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=alenquer
# Processing record 42 of set 3 | mindelo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=mindelo
# Processing record 43 of set 3 | geraldton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=geraldton
# Processing record 44 of set 3 | saint-philippe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=saint-philippe
# Processing record 45 of set 3 | los llanos de aridane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=los llanos de aridane
# Processing record 46 of set 3 | swan hill
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=swan hill
# Processing record 47 of set 3 | ancud
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=ancud
# Processing record 48 of set 3 | new norfolk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=new norfolk
# Processing record 49 of set 3 | conakry
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=conakry
# Processing record 50 of set 3 | ailigandi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=ailigandi
# Processing record 0 of set 4 | tsihombe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=tsihombe
# City not found!
# Processing record 1 of set 4 | andenes
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=andenes
# Processing record 2 of set 4 | elko
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=elko
# Processing record 3 of set 4 | bengkulu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=bengkulu
# Processing record 4 of set 4 | whyalla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=whyalla
# Processing record 5 of set 4 | marcona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=marcona
# City not found!
# Processing record 6 of set 4 | ratne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=ratne
# Processing record 7 of set 4 | la ronge
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=la ronge
# Processing record 8 of set 4 | trelew
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=trelew
# Processing record 9 of set 4 | phan thiet
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=phan thiet
# Processing record 10 of set 4 | shubarshi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=shubarshi
# Processing record 11 of set 4 | martil
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=martil
# Processing record 12 of set 4 | langres
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=langres
# Processing record 13 of set 4 | tecpan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=tecpan
# Processing record 14 of set 4 | kirakira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=kirakira
# Processing record 15 of set 4 | orlik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=orlik
# Processing record 16 of set 4 | taoudenni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=taoudenni
# Processing record 17 of set 4 | shelburne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=shelburne
# Processing record 18 of set 4 | tecate
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=tecate
# Processing record 19 of set 4 | batemans bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=batemans bay
# Processing record 20 of set 4 | takoradi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=takoradi
# Processing record 21 of set 4 | kabare
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=kabare
# Processing record 22 of set 4 | kamenskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=kamenskoye
# City not found!
# Processing record 23 of set 4 | port blair
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=port blair
# Processing record 24 of set 4 | dwarka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=dwarka
# Processing record 25 of set 4 | kashi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=kashi
# Processing record 26 of set 4 | kangaatsiaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=kangaatsiaq
# Processing record 27 of set 4 | buala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=buala
# Processing record 28 of set 4 | jawhar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=jawhar
# Processing record 29 of set 4 | jamestown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=jamestown
# Processing record 30 of set 4 | yining
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=yining
# Processing record 31 of set 4 | coahuayana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=coahuayana
# Processing record 32 of set 4 | namibe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=namibe
# Processing record 33 of set 4 | pasaje
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=pasaje
# Processing record 34 of set 4 | veseloyarsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=veseloyarsk
# Processing record 35 of set 4 | jiroft
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=jiroft
# City not found!
# Processing record 36 of set 4 | mapiripan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=mapiripan
# Processing record 37 of set 4 | coquimbo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=coquimbo
# Processing record 38 of set 4 | morro bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=morro bay
# Processing record 39 of set 4 | kaohsiung
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=kaohsiung
# Processing record 40 of set 4 | marzuq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=marzuq
# Processing record 41 of set 4 | chokurdakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=chokurdakh
# Processing record 42 of set 4 | labrea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=labrea
# Processing record 43 of set 4 | sencha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=sencha
# Processing record 44 of set 4 | ryotsu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=ryotsu
# Processing record 45 of set 4 | zomin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=zomin
# Processing record 46 of set 4 | ust-nera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=ust-nera
# Processing record 47 of set 4 | bathsheba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=bathsheba
# Processing record 48 of set 4 | walvis bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=walvis bay
# Processing record 49 of set 4 | margate
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=margate
# Processing record 50 of set 4 | colares
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=colares
# Processing record 0 of set 5 | mwinilunga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=mwinilunga
# Processing record 1 of set 5 | podbelsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=podbelsk
# City not found!
# Processing record 2 of set 5 | umba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=umba
# Processing record 3 of set 5 | kruisfontein
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=kruisfontein
# Processing record 4 of set 5 | manacapuru
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=manacapuru
# Processing record 5 of set 5 | staryy merchyk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=staryy merchyk
# Processing record 6 of set 5 | mutsamudu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=mutsamudu
# City not found!
# Processing record 7 of set 5 | harper
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=harper
# Processing record 8 of set 5 | bokspits
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=bokspits
# City not found!
# Processing record 9 of set 5 | leningradskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=leningradskiy
# Processing record 10 of set 5 | sebring
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=sebring
# Processing record 11 of set 5 | tavda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=tavda
# Processing record 12 of set 5 | malangali
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=malangali
# Processing record 13 of set 5 | padang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=padang
# Processing record 14 of set 5 | pevek
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=pevek
# Processing record 15 of set 5 | sai buri
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=sai buri
# Processing record 16 of set 5 | unye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=unye
# City not found!
# Processing record 17 of set 5 | champerico
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=champerico
# Processing record 18 of set 5 | fort nelson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=fort nelson
# Processing record 19 of set 5 | coihaique
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=coihaique
# Processing record 20 of set 5 | soloneshnoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=soloneshnoye
# Processing record 21 of set 5 | tasiilaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=tasiilaq
# Processing record 22 of set 5 | mergui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=mergui
# City not found!
# Processing record 23 of set 5 | sao jose da coroa grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=sao jose da coroa grande
# Processing record 24 of set 5 | praia da vitoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=praia da vitoria
# Processing record 25 of set 5 | suntar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=suntar
# Processing record 26 of set 5 | brigantine
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=brigantine
# Processing record 27 of set 5 | san patricio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=san patricio
# Processing record 28 of set 5 | rawson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=rawson
# Processing record 29 of set 5 | leh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=leh
# Processing record 30 of set 5 | cherskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=cherskiy
# Processing record 31 of set 5 | arzgir
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=arzgir
# Processing record 32 of set 5 | victoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=victoria
# Processing record 33 of set 5 | zyryanka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=zyryanka
# Processing record 34 of set 5 | we
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=we
# City not found!
# Processing record 35 of set 5 | west richland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=west richland
# Processing record 36 of set 5 | beira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=beira
# Processing record 37 of set 5 | louisbourg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=louisbourg
# City not found!
# Processing record 38 of set 5 | waingapu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=waingapu
# Processing record 39 of set 5 | vieste
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=vieste
# Processing record 40 of set 5 | bilma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=bilma
# Processing record 41 of set 5 | furstenwalde
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=furstenwalde
# Processing record 42 of set 5 | calabozo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=calabozo
# Processing record 43 of set 5 | sitio novo do tocantins
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=sitio novo do tocantins
# Processing record 44 of set 5 | constitucion
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=constitucion
# Processing record 45 of set 5 | doha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=doha
# Processing record 46 of set 5 | svetlaya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=svetlaya
# Processing record 47 of set 5 | ponta delgada
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=ponta delgada
# Processing record 48 of set 5 | carndonagh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=carndonagh
# Processing record 49 of set 5 | sabang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=sabang
# Processing record 50 of set 5 | jardim
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=jardim
# Processing record 0 of set 6 | berdigestyakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=berdigestyakh
# Processing record 1 of set 6 | najran
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=najran
# Processing record 2 of set 6 | sobolevo
# ...
# Processing record 11 of set 10 | murgab
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=murgab
# Processing record 12 of set 10 | lipari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=lipari
# Processing record 13 of set 10 | mount isa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=mount isa
# Processing record 14 of set 10 | shitanjing
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=shitanjing
# Processing record 15 of set 10 | sibu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=sibu
# Processing record 16 of set 10 | fare
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=fare
# Processing record 17 of set 10 | turiacu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=turiacu
# Processing record 18 of set 10 | wad rawah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=wad rawah
# Processing record 19 of set 10 | tshela
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=tshela
# Processing record 20 of set 10 | baft
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=baft
# Processing record 21 of set 10 | yoichi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=yoichi
# Processing record 22 of set 10 | arlit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=arlit
# Processing record 23 of set 10 | yunjinghong
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=yunjinghong
# City not found!
# Processing record 24 of set 10 | charyshskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=charyshskoye
# Processing record 25 of set 10 | cuauhtemoc
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=cuauhtemoc
# Processing record 26 of set 10 | tarudant
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=tarudant
# City not found!
# Processing record 27 of set 10 | mangrol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=mangrol
# Processing record 28 of set 10 | tignere
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=tignere
# Processing record 29 of set 10 | grand baie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=grand baie
# Processing record 30 of set 10 | olga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=olga
# Processing record 31 of set 10 | bay roberts
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=bay roberts
# Processing record 32 of set 10 | biak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=biak
# Processing record 33 of set 10 | praia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=praia
# Processing record 34 of set 10 | shenkursk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=shenkursk
# Processing record 35 of set 10 | cockburn town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=cockburn town
# Processing record 36 of set 10 | viytivka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=viytivka
# Processing record 37 of set 10 | issum
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=issum
# Processing record 38 of set 10 | palmer
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=palmer
# Processing record 39 of set 10 | sakhnin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=sakhnin
# Processing record 40 of set 10 | zheleznodorozhnyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=zheleznodorozhnyy
# Processing record 41 of set 10 | ilulissat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=ilulissat
# Processing record 42 of set 10 | clearwater
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=clearwater
# Processing record 43 of set 10 | broken hill
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=broken hill
# Processing record 44 of set 10 | kavieng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=kavieng
# Processing record 45 of set 10 | oktyabrskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=oktyabrskoye
# Processing record 46 of set 10 | morehead
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=morehead
# Processing record 47 of set 10 | vodnyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=vodnyy
# Processing record 48 of set 10 | bignona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=bignona
# Processing record 49 of set 10 | arawa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=arawa
# Processing record 50 of set 10 | kardla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=kardla
# Processing record 0 of set 11 | hervey bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=hervey bay
# Processing record 1 of set 11 | puerto del rosario
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=puerto del rosario
# Processing record 2 of set 11 | tulungagung
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=tulungagung
# Processing record 3 of set 11 | rockhampton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=rockhampton
# Processing record 4 of set 11 | novikovo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=novikovo
# Processing record 5 of set 11 | tungkang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=tungkang
# City not found!
# Processing record 6 of set 11 | jerantut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=jerantut
# Processing record 7 of set 11 | la romana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=la romana
# Processing record 8 of set 11 | mana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=mana
# Processing record 9 of set 11 | banikoara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=banikoara
# Processing record 10 of set 11 | anamur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=anamur
# Processing record 11 of set 11 | abnub
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=abnub
# Processing record 12 of set 11 | galiwinku
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=galiwinku
# City not found!
# Processing record 13 of set 11 | sanchazi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=sanchazi
# Processing record 14 of set 11 | shakawe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=shakawe
# Processing record 15 of set 11 | husavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=husavik
# Processing record 16 of set 11 | khani
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=khani
# Processing record 17 of set 11 | balykshi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=balykshi
# City not found!
# Processing record 18 of set 11 | alto araguaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=alto araguaia
# Processing record 19 of set 11 | talcahuano
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=talcahuano
# Processing record 20 of set 11 | togur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=togur
# Processing record 21 of set 11 | tooele
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=tooele
# Processing record 22 of set 11 | fuxin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=fuxin
# Processing record 23 of set 11 | aljezur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=aljezur
# Processing record 24 of set 11 | impfondo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=impfondo
# Processing record 25 of set 11 | bur gabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=bur gabo
# City not found!
# Processing record 26 of set 11 | sao francisco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=sao francisco
# Processing record 27 of set 11 | sao joao da barra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=sao joao da barra
# Processing record 28 of set 11 | djambala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=djambala
# Processing record 29 of set 11 | harrismith
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=harrismith
# Processing record 30 of set 11 | aitape
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=aitape
# Processing record 31 of set 11 | haimen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=haimen
# Processing record 32 of set 11 | reconquista
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=reconquista
# Processing record 33 of set 11 | patrocinio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=patrocinio
# Processing record 34 of set 11 | dingle
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=dingle
# Processing record 35 of set 11 | sakakah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=sakakah
# Processing record 36 of set 11 | santiago
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=santiago
# Processing record 37 of set 11 | plettenberg bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=plettenberg bay
# Processing record 38 of set 11 | santa lucia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=santa lucia
# Processing record 39 of set 11 | adrar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=adrar
# Processing record 40 of set 11 | itarsi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=itarsi
# Processing record 41 of set 11 | westport
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=westport
# Processing record 42 of set 11 | acapulco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=acapulco
# Processing record 43 of set 11 | ormara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=ormara
# Processing record 44 of set 11 | sioux city
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=sioux city
# Processing record 45 of set 11 | pedernales
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=pedernales
# Processing record 46 of set 11 | yanam
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=yanam
# Processing record 47 of set 11 | kalianget
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=kalianget
# Processing record 48 of set 11 | sangar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=sangar
# Processing record 49 of set 11 | portel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=portel
# Processing record 50 of set 11 | labuan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=labuan
# Processing record 0 of set 12 | bonthe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=bonthe
# Processing record 1 of set 12 | rolim de moura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=rolim de moura
# City not found!
# Processing record 2 of set 12 | puksoozero
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=puksoozero
# Processing record 3 of set 12 | makat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=makat
# Processing record 4 of set 12 | issoire
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=issoire
# Processing record 5 of set 12 | linxia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=linxia
# Processing record 6 of set 12 | helsinki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=helsinki
# Processing record 7 of set 12 | santa isabel do rio negro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=santa isabel do rio negro
# Processing record 8 of set 12 | south houston
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=south houston
# Processing record 9 of set 12 | novobelokatay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=novobelokatay
# Processing record 10 of set 12 | lahaina
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a80f11f6feb10847648355642a81128e&q=lahaina
# -------------------------
# Data Retrieval Complete
# -------------------------

# %%
weather_data = {
    "City": new_cities,
    "Cloudiness" : cloudiness,
    "Country" : country,
    "Date" : date,
    "Humidity" : humidity,
    "Temp": temp,
    "Lat" : lat,
    "Lng" : lng,   
    "Wind Speed" : wind
}
weather_data_df = pd.DataFrame(weather_data)
weather_data_df.count()
# Out:
# City          567
# Cloudiness    567
# Country       567
# Date          567
# Humidity      567
# Temp          567
# Lat           567
# Lng           567
# Wind Speed    567
# dtype: int64

# %%
weather_data_df
# Out:
#                           City  Cloudiness Country        Date  Humidity  \
# 0                  yellowknife           5      CA  1579786462        83
# 1                       kodiak          40      US  1579786731        57
# 2                   georgetown          20      MY  1579786596        70
# 3                sao sebastiao         100      BR  1579786680        82
# 4                san cristobal          40      VE  1579786732       100
# ..                         ...         ...     ...         ...       ...
# 562                   helsinki          75      FI  1579786849        86
# 563  santa isabel do rio negro          85      BR  1579786895        50
# 564              south houston          90      US  1579786895       100
# 565              novobelokatay          97      RU  1579786895        94
# 566                    lahaina           1      US  1579786803        82
#
#       Temp    Lat     Lng  Wind Speed
# 0    -9.00  62.46 -114.35        6.93
# 1    21.20  57.79 -152.41        9.17
# 2    86.00   5.41  100.34        5.82
# 3    73.67 -23.76  -45.41        8.99
# 4    73.40   7.77  -72.22        2.75
# ..     ...    ...     ...         ...
# 562  35.01  60.17   24.94        9.17
# 563  91.71  -0.41  -65.02        4.27
# 564  61.00  29.66  -95.24        3.36
# 565  15.44  55.71   58.95        9.04
# 566  66.00  20.88 -156.68        5.82
#
# [567 rows x 9 columns]

# %%
plt.scatter(x=weather_data_df['Lat'], y = weather_data_df['Temp'], label = 'Temperature')
plt.xlabel('Latitude')
plt.ylabel('Temperature (f)')
plt.legend(loc='best')
plt.title('Temperature vs Latitude')
plt.show()

# %%
plt.scatter(x=weather_data_df['Lat'], y = weather_data_df['Humidity'], label = 'Humidity')
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.legend(loc='best')
plt.title('Humidity vs Latitude')
plt.show()

# %%
plt.scatter(x=weather_data_df['Lat'], y = weather_data_df['Cloudiness'], label = 'Cloudiness')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.legend(loc='best')
plt.title('Cloudiness vs Latitude')
plt.show()

# %%
plt.scatter(x=weather_data_df['Lat'], y = weather_data_df['Wind Speed'], label='Wind Speed')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.legend(loc='best')
plt.title('Wind Speed vs Latitude')
plt.show()

# %%
northern_df = weather_data_df.loc[weather_data_df['Lat']>=0]
northern_df
# Out:
#               City  Cloudiness Country        Date  Humidity   Temp    Lat  \
# 0      yellowknife           5      CA  1579786462        83  -9.00  62.46
# 1           kodiak          40      US  1579786731        57  21.20  57.79
# 2       georgetown          20      MY  1579786596        70  86.00   5.41
# 4    san cristobal          40      VE  1579786732       100  73.40   7.77
# 5           kaseda          75      JP  1579786732       100  55.40  31.42
# ..             ...         ...     ...         ...       ...    ...    ...
# 561         linxia         100      CN  1579786894        95  19.69  35.60
# 562       helsinki          75      FI  1579786849        86  35.01  60.17
# 564  south houston          90      US  1579786895       100  61.00  29.66
# 565  novobelokatay          97      RU  1579786895        94  15.44  55.71
# 566        lahaina           1      US  1579786803        82  66.00  20.88
#
#         Lng  Wind Speed
# 0   -114.35        6.93
# 1   -152.41        9.17
# 2    100.34        5.82
# 4    -72.22        2.75
# 5    130.32        6.93
# ..      ...         ...
# 561  103.21        4.29
# 562   24.94        9.17
# 564  -95.24        3.36
# 565   58.95        9.04
# 566 -156.68        5.82
#
# [393 rows x 9 columns]

# %%
southern_df = weather_data_df.loc[weather_data_df['Lat']<0]
southern_df
# Out:
#                           City  Cloudiness Country        Date  Humidity  \
# 3                sao sebastiao         100      BR  1579786680        82
# 6                 puerto ayora          90      EC  1579786732        78
# 7        mayor pablo lagerenza         100      PY  1579786732        42
# 8                      ahipara           3      NZ  1579786732        80
# 9                 punta arenas          40      CL  1579786733        81
# ..                         ...         ...     ...         ...       ...
# 542                   santiago          47      CL  1579786891        60
# 543            plettenberg bay          58      ZA  1579786892        81
# 553                  kalianget          34      ID  1579786893        77
# 555                     portel          34      BR  1579786893        56
# 563  santa isabel do rio negro          85      BR  1579786895        50
#
#       Temp    Lat     Lng  Wind Speed
# 3    73.67 -23.76  -45.41        8.99
# 6    77.00  -0.74  -90.35        6.93
# 7    90.14 -19.93  -60.77       15.52
# 8    65.98 -35.17  173.17        7.16
# 9    51.80 -53.15  -70.92       16.11
# ..     ...    ...     ...         ...
# 542  80.01 -33.46  -70.65        2.24
# 543  68.40 -34.05   23.37       20.87
# 553  82.67  -7.05  113.93        5.46
# 555  88.47  -1.94  -50.82        4.99
# 563  91.71  -0.41  -65.02        4.27
#
# [174 rows x 9 columns]

# %% [markdown]
# # Northern Hemisphere - Temperature vs. Latitude Linear Regression

# %%
x = northern_df['Lat']
y = northern_df['Temp']
(slope, intercept, rvalues, pvalues, stderr) = stats.linregress(x, y)
regress_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x, y, label='Temperature')
plt.plot(x, regress_values, 'r-')
plt.annotate(line_eq, (10,0), fontsize=15, color='red')
plt.xlabel('Latutude')
plt.ylabel('Temperature (f)')
plt.title('Northern Hemisphere Temperature vs Latitude')
plt.legend(loc='best')
print(f"Corelation coefficient : {rvalues}")
# Out:
# Corelation coefficient : -0.8641779229956505

# %% [markdown]
# In Northern Hemisphere Temperature and lattitude has strong negative relationship, with increase in latitude temperature is decreasing,

# %% [markdown]
# # Southern Hemisphere - Temperature vs. Latitude Linear Regression

# %%
x = southern_df['Lat']
y = southern_df['Temp']
(slope, intercept, rvalues, pvalues, stderr) = stats.linregress(x, y)
regress_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x, y, label='Temperature')
plt.plot(x, regress_values, 'r-')
plt.annotate(line_eq, (-30,50), fontsize=15, color='red')
plt.xlabel('Latutude')
plt.ylabel('Temperature (f)')
plt.title('Southern Hemisphere Temperature vs Latitude')
plt.legend(loc='best')
print(f"Corelation coefficient : {rvalues}")
# Out:
# Corelation coefficient : 0.4340957586686791

# %% [markdown]
# In Southern Hemisphere Temperature and lattitude has some positive relationship, with r value is 0.43

# %% [markdown]
# # Northern Hemisphere - Humidity vs. Latitude Linear Regression

# %%
x = northern_df['Lat']
y = northern_df['Humidity']
(slope, intercept, rvalues, pvalues, stderr) = stats.linregress(x, y)
regress_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x, y, label='Humidity')
plt.plot(x, regress_values, 'r-')
plt.annotate(line_eq, (40,30), fontsize=15, color='red')
plt.xlabel('Latutude')
plt.ylabel('Humidity')
plt.title('Northern Hemisphere Humidity vs Latitude')
plt.legend(loc='best')
print(f"Corelation coefficient : {rvalues}")
# Out:
# Corelation coefficient : 0.4205761601048091

# %% [markdown]
# In Northern Hemisphere there is some positive relationship between Humidity and Latitude with r value: 0.42

# %% [markdown]
# # Southern Hemisphere - Humidity vs. Latitude Linear Regression

# %%
x = southern_df['Lat']
y = southern_df['Humidity']
(slope, intercept, rvalues, pvalues, stderr) = stats.linregress(x, y)
regress_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x, y, label='Humidity')
plt.plot(x, regress_values, 'r-')
plt.annotate(line_eq, (-25,30), fontsize=15, color='red')
plt.xlabel('Latutude')
plt.ylabel('Humidity')
plt.title('Southern Hemisphere Humidity vs Latitude')
plt.legend(loc='best')
print(f"Corelation coefficient : {rvalues}")
# Out:
# Corelation coefficient : 0.26299052134513196

# %% [markdown]
# In Southern Hemisphere there is no relationship between Humidity and Latitude with r value: 0.26

# %% [markdown]
# # Northern Hemisphere - Cloudiness vs. Latitude Linear Regression

# %%
x = northern_df['Lat']
y = northern_df['Cloudiness']
(slope, intercept, rvalues, pvalues, stderr) = stats.linregress(x, y)
regress_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x, y, label='Cloudiness')
plt.plot(x, regress_values, 'r-')
plt.annotate(line_eq, (40,30), fontsize=15, color='red')
plt.xlabel('Latutude')
plt.ylabel('Cloudiness')
plt.title('Northern Hemisphere Cloudiness vs Latitude')
plt.legend(loc='best')
print(f"Corelation coefficient : {rvalues}")
# Out:
# Corelation coefficient : 0.2694678522135189

# %% [markdown]
# In Northern Hemisphere there is no relationship between Cloudiness and Latitude with r value: 0.27

# %% [markdown]
# # Southern Hemisphere - Cloudiness vs. Latitude Linear Regression

# %%
x = southern_df['Lat']
y = southern_df['Cloudiness']
(slope, intercept, rvalues, pvalues, stderr) = stats.linregress(x, y)
regress_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x, y, label='Cloudiness')
plt.plot(x, regress_values, 'r-')
plt.annotate(line_eq, (-50,20), fontsize=15, color='red')
plt.xlabel('Latutude')
plt.ylabel('Cloudiness ')
plt.title('Southern Hemisphere Cloudiness vs Latitude')
plt.legend(loc='best')
print(f"Corelation coefficient : {rvalues}")
# Out:
# Corelation coefficient : 0.3324958896214017

# %% [markdown]
# In Southern Hemisphere there is no relationship between Cloudiness and Latitude with r value: 0.33

# %% [markdown]
# # Northern Hemisphere - Wind Speed vs. Latitude Linear Regression

# %%
x = northern_df['Lat']
y = northern_df['Wind Speed']
(slope, intercept, rvalues, pvalues, stderr) = stats.linregress(x, y)
regress_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x, y, label='Wind Speed')
plt.plot(x, regress_values, 'r-')
plt.annotate(line_eq, (20,40), fontsize=15, color='red')
plt.xlabel('Latutude')
plt.ylabel('Wind Speed (MPH) ')
plt.title('Northern Hemisphere Wind Speed vs Latitude')
plt.legend(loc='best')
print(f"Corelation coefficient : {rvalues}")
# Out:
# Corelation coefficient : 0.19645563645758826

# %% [markdown]
# In Northern Hemisphere there is no relationship between Wind Speed and Latitude with r value: 0.19

# %% [markdown]
# # Southern Hemisphere - Wind Speed vs. Latitude Linear Regression

# %%
x = southern_df['Lat']
y = southern_df['Wind Speed']
(slope, intercept, rvalues, pvalues, stderr) = stats.linregress(x, y)
regress_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x, y, label='Wind Speed')
plt.plot(x, regress_values, 'r-')
plt.annotate(line_eq, (-30,25), fontsize=15, color='red')
plt.xlabel('Latutude')
plt.ylabel('Wind Speed (MPH) ')
plt.title('Southern Hemisphere Wind Speed vs Latitude')
plt.legend(loc='best')
print(f"Corelation coefficient : {rvalues}")
# Out:
# Corelation coefficient : -0.33539204476918033

# %% [markdown]
# In Southern Hemisphere there is some negative relationship between Wind Speed and Latitude with r value: -0.33
